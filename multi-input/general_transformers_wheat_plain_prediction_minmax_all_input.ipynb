# %%
from fastai.vision.all import *
import fastai
import timm
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
import torch
torch.cuda.set_device(0)

# %%
df = pd.read_csv('data/wheat_new.csv',decimal=',')

# %%
name =  'vit_base_patch16_384'

# %%
df
# Out:
#      Unnamed: 0                 file  DAS  plot nº photo nº species
# 0             0   20220517_1 (1).JPG   96        1     (1).   wheat  \
# 1             1   20220517_1 (2).JPG   96        1     (2).   wheat
# 2             2   20220517_1 (3).JPG   96        1     (3).   wheat
# 3             3   20220517_1 (4).JPG   96        1     (4).   wheat
# 4             4   20220602_1 (1).JPG  112        1     (1).   wheat
# ..          ...                  ...  ...      ...      ...     ...
# 251         251  20220615_25 (4).JPG  125       25     (4).   wheat
# 252         252  20220701_25 (1).JPG  141       25     (1).   wheat
# 253         253  20220701_25 (2).JPG  141       25     (2).   wheat
# 254         254  20220701_25 (3).JPG  141       25     (3).   wheat
# 255         255  20220701_25 (4).JPG  141       25     (4).   wheat
#
#     water_treatment management  plot m2  avg_water (L m-2)  ...
# 0                ww       conv       12          3096.2375  ...  \
# 1                ww       conv       12          3096.2375  ...
# 2                ww       conv       12          3096.2375  ...
# 3                ww       conv       12          3096.2375  ...
# 4                ww       conv       12          3096.2375  ...
# ..              ...        ...      ...                ...  ...
# 251               d       conv       12          2752.8000  ...
# 252               d       conv       12          2752.8000  ...
# 253               d       conv       12          2752.8000  ...
# 254               d       conv       12          2752.8000  ...
# 255               d       conv       12          2752.8000  ...
#
#      P (kg microplot-1)  K (kg microplot-1)  avg_height        GA       GGA
# 0                 0.072               0.072     46.9715  0.959407  0.904393  \
# 1                 0.072               0.072     46.9715  0.963030  0.905523
# 2                 0.072               0.072     46.9715  0.953708  0.898722
# 3                 0.072               0.072     46.9715  0.957117  0.898772
# 4                 0.072               0.072     46.9715  0.892348  0.791199
# ..                  ...                 ...         ...       ...       ...
# 251               0.072               0.072     55.2110  0.788544  0.323428
# 252               0.072               0.072     55.2110  0.031868  0.009072
# 253               0.072               0.072     55.2110  0.025828  0.006849
# 254               0.072               0.072     55.2110  0.022065  0.004773
# 255               0.072               0.072     55.2110  0.026765  0.007124
#
#            CSI  NGRDIveg     TGIveg  final yield (kg)  dataset
# 0     5.734098    0.1324  2569.2709              9.15    train
# 1     5.971505    0.1316  2648.0105              9.15    train
# 2     5.765430    0.1331  2736.4337              9.15    train
# 3     6.095965    0.1267  2550.8238              9.15    train
# 4    11.335180    0.1008  1880.2128              9.15    train
# ..         ...       ...        ...               ...      ...
# 251  58.984136    0.0491  2277.6824              7.95     test
# 252  71.532905    0.0342   946.1760              7.95     test
# 253  73.483356    0.0314   867.4491              7.95     test
# 254  78.367629    0.0196   855.3556              7.95     test
# 255  73.384338    0.0265   979.4368              7.95     test
#
# [256 rows x 21 columns]

# %%
scaler = MinMaxScaler()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'file', 'DAS', 'plot nº', 'photo nº', 'species',
#        'water_treatment', 'management', 'plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)', 'dataset'],
#       dtype='object')

# %%
dftrain = df[(df.dataset=='train')]
dftrain.loc[:,['plot m2', 'avg_water (L m-2)',
       'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
       'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
       'final yield (kg)']] = scaler.fit_transform(dftrain[['plot m2', 'avg_water (L m-2)',
       'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
       'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
       'final yield (kg)']])
dfvalid = df[(df.dataset=='validation')]
dftest = df[(df.dataset=='test')]
dfvalid.loc[:,['plot m2', 'avg_water (L m-2)',
       'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
       'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
       'final yield (kg)']] = scaler.transform(dfvalid[['plot m2', 'avg_water (L m-2)',
       'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
       'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
       'final yield (kg)']])        
dftest.loc[:,['plot m2', 'avg_water (L m-2)',
       'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
       'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
       'final yield (kg)']] = scaler.transform(dftest[['plot m2', 'avg_water (L m-2)',
       'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
       'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
       'final yield (kg)']])

# %%
dftrain = pd.concat([dftrain,dfvalid])

# %%
df = pd.concat([dftrain,dftest])

# %%
dftrain.loc[:,'dataset'] =  dftrain['dataset'].apply(lambda x: x=='validation')
df.loc[:,'dataset'] =  df['dataset'].apply(lambda x: x=='test')

# %%
# dftrain.loc[:,'final yield (kg)'] = dftrain['final yield (kg)'].apply(lambda x : (x - 0.8579)/(10.55-0.8579))
# df.loc[:,'final yield (kg)'] = df['final yield (kg)'].apply(lambda x : (x - 0.8579)/(10.55-0.8579))

# %%
from fastai.vision.all import *
callbacks = [
    ShowGraphCallback(),
    # EarlyStoppingCallback(patience=5),
    SaveModelCallback(fname=name+'_all_minmax_new'), #convnext_yield_all_minmax
    # ReduceLROnPlateau()
]

# %%
from fastai.metrics import mae,rmse,mse

# %%
db = DataBlock(blocks = (ImageBlock,CategoryBlock(),CategoryBlock(),CategoryBlock(),
                         RegressionBlock(),RegressionBlock(),RegressionBlock(),RegressionBlock(),
                         RegressionBlock(),RegressionBlock(),RegressionBlock(),RegressionBlock(),
                         RegressionBlock(),RegressionBlock(),RegressionBlock(),RegressionBlock()),
                 get_x=[ColReader('file',pref='wheat_all/'),
                        ColReader('species'),
                        ColReader('water_treatment'),
                        ColReader('management'),
                        ColReader('plot m2'),
                        ColReader('avg_water (L m-2)'),
                        ColReader('N (kg microplot-1)'),
                        ColReader('P (kg microplot-1)'),
                        ColReader('K (kg microplot-1)'),
                        ColReader('avg_height'),
                        ColReader('GA'),
                        ColReader('GGA'),
                        ColReader('CSI'),
                        ColReader('NGRDIveg'),
                        ColReader('TGIveg')
                       ],
                 get_y=[ColReader('final yield (kg)')],
                 splitter=ColSplitter(col='dataset'),    
                 item_tfms = Resize(512),
                 batch_tfms=[*aug_transforms(size=384,flip_vert=True,
                                            max_zoom=1.0), Normalize.from_stats(*imagenet_stats)],
               n_inp=15)
dls = db.dataloaders(dftrain,bs=2)

# %%
class MultiInputModel(Module):
  "A three-headed model given a `body` and `n` output features"
  def __init__(self, body:nn.Sequential):
    # nf = num_features_model(nn.Sequential(*body.children()))
    self.body = body
    self.image = create_head(1, 10)
    self.combine = nn.Sequential(
            nn.Linear(in_features=24, out_features=1, bias=False)
        )
    
    
  
  def forward(self, x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14):
    y = self.body(x0)
    y = self.image(y)
    final_yield = self.combine(torch.cat([y,torch.reshape(x1,(x1.shape[0],1)),
                                     torch.reshape(x2,(x2.shape[0],1)),
                                     torch.reshape(x3,(x3.shape[0],1)),
                                     torch.reshape(x4,(x4.shape[0],1)),
                                     torch.reshape(x5,(x5.shape[0],1)),
                                     torch.reshape(x6,(x6.shape[0],1)),
                                     torch.reshape(x7,(x7.shape[0],1)),
                                     torch.reshape(x8,(x8.shape[0],1)),
                                     torch.reshape(x9,(x9.shape[0],1)),
                                     torch.reshape(x10,(x10.shape[0],1)),
                                     torch.reshape(x11,(x11.shape[0],1)),
                                     torch.reshape(x12,(x12.shape[0],1)),
                                     torch.reshape(x13,(x13.shape[0],1)),
                                     torch.reshape(x14,(x14.shape[0],1))],1))
    return final_yield

# %%
model = timm.create_model(name,num_classes=1,pretrained=True)
body = nn.Sequential(*list(model.children())[:-1])
net = MultiInputModel(body)

# %%
learn = Learner(dls, net, loss_func=MSELossFlat(), metrics=[mae,rmse,mse],cbs=callbacks)

# %%
# learn.lr_find()

# %%
learn.freeze()

# %%
learn.fit_one_cycle(30,lr_max=1e-3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae</th>
#       <th>_rmse</th>
#       <th>mse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.314868</td>
#       <td>0.312895</td>
#       <td>0.415633</td>
#       <td>0.559370</td>
#       <td>0.312895</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.290270</td>
#       <td>0.277680</td>
#       <td>0.384172</td>
#       <td>0.526953</td>
#       <td>0.277680</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.252002</td>
#       <td>0.191174</td>
#       <td>0.316697</td>
#       <td>0.437235</td>
#       <td>0.191174</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.203194</td>
#       <td>0.798446</td>
#       <td>0.844093</td>
#       <td>0.893558</td>
#       <td>0.798446</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.121493</td>
#       <td>0.066537</td>
#       <td>0.183531</td>
#       <td>0.257948</td>
#       <td>0.066537</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.095624</td>
#       <td>0.035685</td>
#       <td>0.163829</td>
#       <td>0.188904</td>
#       <td>0.035685</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.052641</td>
#       <td>3.747206</td>
#       <td>1.911032</td>
#       <td>1.935770</td>
#       <td>3.747206</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.029469</td>
#       <td>0.403149</td>
#       <td>0.628528</td>
#       <td>0.634940</td>
#       <td>0.403149</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.020143</td>
#       <td>0.006922</td>
#       <td>0.056885</td>
#       <td>0.083199</td>
#       <td>0.006922</td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.012125</td>
#       <td>0.002061</td>
#       <td>0.036760</td>
#       <td>0.045398</td>
#       <td>0.002061</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.007958</td>
#       <td>0.001147</td>
#       <td>0.025483</td>
#       <td>0.033873</td>
#       <td>0.001147</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.005018</td>
#       <td>0.000642</td>
#       <td>0.018885</td>
#       <td>0.025331</td>
#       <td>0.000642</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.003482</td>
#       <td>0.000636</td>
#       <td>0.018948</td>
#       <td>0.025211</td>
#       <td>0.000636</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.002974</td>
#       <td>0.000231</td>
#       <td>0.011610</td>
#       <td>0.015209</td>
#       <td>0.000231</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.002664</td>
#       <td>0.000347</td>
#       <td>0.013060</td>
#       <td>0.018629</td>
#       <td>0.000347</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.002452</td>
#       <td>0.000178</td>
#       <td>0.011188</td>
#       <td>0.013349</td>
#       <td>0.000178</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.002300</td>
#       <td>0.000203</td>
#       <td>0.011859</td>
#       <td>0.014254</td>
#       <td>0.000203</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.002463</td>
#       <td>0.000268</td>
#       <td>0.012497</td>
#       <td>0.016377</td>
#       <td>0.000268</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.002355</td>
#       <td>0.001074</td>
#       <td>0.023220</td>
#       <td>0.032778</td>
#       <td>0.001074</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.002401</td>
#       <td>0.000162</td>
#       <td>0.010617</td>
#       <td>0.012730</td>
#       <td>0.000162</td>
#       <td>00:40</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.002166</td>
#       <td>0.000196</td>
#       <td>0.010655</td>
#       <td>0.014013</td>
#       <td>0.000196</td>
#       <td>00:40</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.002125</td>
#       <td>0.000237</td>
#       <td>0.011298</td>
#       <td>0.015386</td>
#       <td>0.000237</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.002222</td>
#       <td>0.000211</td>
#       <td>0.011245</td>
#       <td>0.014524</td>
#       <td>0.000211</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.002241</td>
#       <td>0.000095</td>
#       <td>0.007355</td>
#       <td>0.009754</td>
#       <td>0.000095</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.002148</td>
#       <td>0.000146</td>
#       <td>0.009719</td>
#       <td>0.012102</td>
#       <td>0.000146</td>
#       <td>00:40</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.002206</td>
#       <td>0.000111</td>
#       <td>0.008749</td>
#       <td>0.010538</td>
#       <td>0.000111</td>
#       <td>00:40</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.002077</td>
#       <td>0.000099</td>
#       <td>0.008371</td>
#       <td>0.009960</td>
#       <td>0.000099</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.002049</td>
#       <td>0.000098</td>
#       <td>0.008375</td>
#       <td>0.009892</td>
#       <td>0.000098</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.002001</td>
#       <td>0.000108</td>
#       <td>0.008808</td>
#       <td>0.010413</td>
#       <td>0.000108</td>
#       <td>00:40</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.002118</td>
#       <td>0.000099</td>
#       <td>0.008455</td>
#       <td>0.009954</td>
#       <td>0.000099</td>
#       <td>00:39</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.31289491057395935.
# Better model found at epoch 1 with valid_loss value: 0.2776799201965332.
# Better model found at epoch 2 with valid_loss value: 0.19117411971092224.
# Better model found at epoch 4 with valid_loss value: 0.06653702259063721.
# Better model found at epoch 5 with valid_loss value: 0.03568490967154503.
# Better model found at epoch 8 with valid_loss value: 0.006922069005668163.
# Better model found at epoch 9 with valid_loss value: 0.002060970524325967.
# Better model found at epoch 10 with valid_loss value: 0.0011473585618659854.
# Better model found at epoch 11 with valid_loss value: 0.000641635968349874.
# Better model found at epoch 12 with valid_loss value: 0.0006356193334795535.
# Better model found at epoch 13 with valid_loss value: 0.00023129972396418452.
# Better model found at epoch 15 with valid_loss value: 0.00017820135690271854.
# Better model found at epoch 19 with valid_loss value: 0.00016206248255912215.
# Better model found at epoch 23 with valid_loss value: 9.514136763755232e-05.

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(30,lr_max=1e-4)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae</th>
#       <th>_rmse</th>
#       <th>mse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.001811</td>
#       <td>0.010707</td>
#       <td>0.087551</td>
#       <td>0.103472</td>
#       <td>0.010707</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.001855</td>
#       <td>0.010715</td>
#       <td>0.088187</td>
#       <td>0.103511</td>
#       <td>0.010715</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.001850</td>
#       <td>0.010677</td>
#       <td>0.087166</td>
#       <td>0.103328</td>
#       <td>0.010677</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.001800</td>
#       <td>0.010646</td>
#       <td>0.087702</td>
#       <td>0.103181</td>
#       <td>0.010646</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.001830</td>
#       <td>0.010650</td>
#       <td>0.087524</td>
#       <td>0.103198</td>
#       <td>0.010650</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.001767</td>
#       <td>0.010747</td>
#       <td>0.087958</td>
#       <td>0.103670</td>
#       <td>0.010747</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.001783</td>
#       <td>0.010733</td>
#       <td>0.088076</td>
#       <td>0.103602</td>
#       <td>0.010733</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.001780</td>
#       <td>0.010530</td>
#       <td>0.087282</td>
#       <td>0.102615</td>
#       <td>0.010530</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.001795</td>
#       <td>0.010671</td>
#       <td>0.087642</td>
#       <td>0.103299</td>
#       <td>0.010671</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.001813</td>
#       <td>0.010602</td>
#       <td>0.087883</td>
#       <td>0.102964</td>
#       <td>0.010602</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.001801</td>
#       <td>0.010657</td>
#       <td>0.087760</td>
#       <td>0.103231</td>
#       <td>0.010657</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.001769</td>
#       <td>0.010649</td>
#       <td>0.087908</td>
#       <td>0.103195</td>
#       <td>0.010649</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.001788</td>
#       <td>0.010613</td>
#       <td>0.088518</td>
#       <td>0.103022</td>
#       <td>0.010613</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.001775</td>
#       <td>0.010638</td>
#       <td>0.088393</td>
#       <td>0.103141</td>
#       <td>0.010638</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.001781</td>
#       <td>0.010593</td>
#       <td>0.088023</td>
#       <td>0.102921</td>
#       <td>0.010593</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.001795</td>
#       <td>0.010561</td>
#       <td>0.087987</td>
#       <td>0.102768</td>
#       <td>0.010561</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.001755</td>
#       <td>0.010591</td>
#       <td>0.088252</td>
#       <td>0.102914</td>
#       <td>0.010591</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.001773</td>
#       <td>0.010575</td>
#       <td>0.088084</td>
#       <td>0.102833</td>
#       <td>0.010575</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.001730</td>
#       <td>0.010587</td>
#       <td>0.088170</td>
#       <td>0.102893</td>
#       <td>0.010587</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.001820</td>
#       <td>0.010598</td>
#       <td>0.087725</td>
#       <td>0.102945</td>
#       <td>0.010598</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.001773</td>
#       <td>0.010562</td>
#       <td>0.087504</td>
#       <td>0.102770</td>
#       <td>0.010562</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.001752</td>
#       <td>0.010553</td>
#       <td>0.087659</td>
#       <td>0.102729</td>
#       <td>0.010553</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.001752</td>
#       <td>0.010543</td>
#       <td>0.087630</td>
#       <td>0.102678</td>
#       <td>0.010543</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.001816</td>
#       <td>0.010559</td>
#       <td>0.087305</td>
#       <td>0.102758</td>
#       <td>0.010559</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.001812</td>
#       <td>0.010548</td>
#       <td>0.087571</td>
#       <td>0.102704</td>
#       <td>0.010548</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.001729</td>
#       <td>0.010554</td>
#       <td>0.087860</td>
#       <td>0.102732</td>
#       <td>0.010554</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.001717</td>
#       <td>0.010554</td>
#       <td>0.087651</td>
#       <td>0.102733</td>
#       <td>0.010554</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.001749</td>
#       <td>0.010538</td>
#       <td>0.087338</td>
#       <td>0.102656</td>
#       <td>0.010538</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.001757</td>
#       <td>0.010548</td>
#       <td>0.087663</td>
#       <td>0.102705</td>
#       <td>0.010548</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.001757</td>
#       <td>0.010540</td>
#       <td>0.087606</td>
#       <td>0.102663</td>
#       <td>0.010540</td>
#       <td>00:19</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.010706513188779354.
# Better model found at epoch 2 with valid_loss value: 0.010676582343876362.
# Better model found at epoch 3 with valid_loss value: 0.010646306909620762.
# Better model found at epoch 7 with valid_loss value: 0.010529757477343082.

# %%
dls = db.dataloaders(df,bs=4)
learn.dls=dls

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
preds,gt = learn.get_preds()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
mean_absolute_error(gt*(10.55-0.8579)+0.8579,preds*(10.55-0.8579)+0.8579)
# Out:
# 0.84594643

# %%
mean_squared_error(gt*(10.55-0.8579)+0.8579,preds*(10.55-0.8579)+0.8579)
# Out:
# 0.98913157

# %%
math.sqrt(mean_squared_error(gt*(10.55-0.8579)+0.8579,preds*(10.55-0.8579)+0.8579))
# Out:
# 0.9945509387971868
