# %%
from fastai.vision.all import *
import fastai
import timm
import pandas as pd
from sklearn.preprocessing import MinMaxScaler,StandardScaler,Normalizer

# %%
import torch
torch.cuda.set_device(3)

# %%
df = pd.read_csv('data/wheat_new.csv',decimal=',')

# %%
name = 'volo_d2_384'

# %%
df
# Out:
#      Unnamed: 0                 file  DAS  plot nº photo nº species
# 0             0   20220517_1 (1).JPG   96        1     (1).   wheat  \
# 1             1   20220517_1 (2).JPG   96        1     (2).   wheat
# 2             2   20220517_1 (3).JPG   96        1     (3).   wheat
# 3             3   20220517_1 (4).JPG   96        1     (4).   wheat
# 4             4   20220602_1 (1).JPG  112        1     (1).   wheat
# ..          ...                  ...  ...      ...      ...     ...
# 251         251  20220615_25 (4).JPG  125       25     (4).   wheat
# 252         252  20220701_25 (1).JPG  141       25     (1).   wheat
# 253         253  20220701_25 (2).JPG  141       25     (2).   wheat
# 254         254  20220701_25 (3).JPG  141       25     (3).   wheat
# 255         255  20220701_25 (4).JPG  141       25     (4).   wheat
#
#     water_treatment management  plot m2  avg_water (L m-2)  ...
# 0                ww       conv       12          3096.2375  ...  \
# 1                ww       conv       12          3096.2375  ...
# 2                ww       conv       12          3096.2375  ...
# 3                ww       conv       12          3096.2375  ...
# 4                ww       conv       12          3096.2375  ...
# ..              ...        ...      ...                ...  ...
# 251               d       conv       12          2752.8000  ...
# 252               d       conv       12          2752.8000  ...
# 253               d       conv       12          2752.8000  ...
# 254               d       conv       12          2752.8000  ...
# 255               d       conv       12          2752.8000  ...
#
#      P (kg microplot-1)  K (kg microplot-1)  avg_height        GA       GGA
# 0                 0.072               0.072     46.9715  0.959407  0.904393  \
# 1                 0.072               0.072     46.9715  0.963030  0.905523
# 2                 0.072               0.072     46.9715  0.953708  0.898722
# 3                 0.072               0.072     46.9715  0.957117  0.898772
# 4                 0.072               0.072     46.9715  0.892348  0.791199
# ..                  ...                 ...         ...       ...       ...
# 251               0.072               0.072     55.2110  0.788544  0.323428
# 252               0.072               0.072     55.2110  0.031868  0.009072
# 253               0.072               0.072     55.2110  0.025828  0.006849
# 254               0.072               0.072     55.2110  0.022065  0.004773
# 255               0.072               0.072     55.2110  0.026765  0.007124
#
#            CSI  NGRDIveg     TGIveg  final yield (kg)  dataset
# 0     5.734098    0.1324  2569.2709              9.15    train
# 1     5.971505    0.1316  2648.0105              9.15    train
# 2     5.765430    0.1331  2736.4337              9.15    train
# 3     6.095965    0.1267  2550.8238              9.15    train
# 4    11.335180    0.1008  1880.2128              9.15    train
# ..         ...       ...        ...               ...      ...
# 251  58.984136    0.0491  2277.6824              7.95     test
# 252  71.532905    0.0342   946.1760              7.95     test
# 253  73.483356    0.0314   867.4491              7.95     test
# 254  78.367629    0.0196   855.3556              7.95     test
# 255  73.384338    0.0265   979.4368              7.95     test
#
# [256 rows x 21 columns]

# %%
scaler = StandardScaler()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'file', 'DAS', 'plot nº', 'photo nº', 'species',
#        'water_treatment', 'management', 'plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)', 'dataset'],
#       dtype='object')

# %%
dftrain = df[(df.dataset=='train')]
dftrain.loc[:,['plot m2', 'avg_water (L m-2)',
       'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
       'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
       'final yield (kg)']] = scaler.fit_transform(dftrain[['plot m2', 'avg_water (L m-2)',
       'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
       'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
       'final yield (kg)']])
dfvalid = df[(df.dataset=='validation')]
dftest = df[(df.dataset=='test')]
dfvalid.loc[:,['plot m2', 'avg_water (L m-2)',
       'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
       'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
       'final yield (kg)']] = scaler.transform(dfvalid[['plot m2', 'avg_water (L m-2)',
       'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
       'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
       'final yield (kg)']])        
dftest.loc[:,['plot m2', 'avg_water (L m-2)',
       'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
       'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
       'final yield (kg)']] = scaler.transform(dftest[['plot m2', 'avg_water (L m-2)',
       'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
       'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
       'final yield (kg)']])

# %%
dftrain = pd.concat([dftrain,dfvalid])

# %%
df = pd.concat([dftrain,dftest])

# %%
dftrain.loc[:,'dataset'] =  dftrain['dataset'].apply(lambda x: x=='validation')
df.loc[:,'dataset'] =  df['dataset'].apply(lambda x: x=='test')

# %%
# dftrain.loc[:,'final yield (kg)'] = dftrain['final yield (kg)'].apply(lambda x : (x - 0.8579)/(10.55-0.8579))
# df.loc[:,'final yield (kg)'] = df['final yield (kg)'].apply(lambda x : (x - 0.8579)/(10.55-0.8579))

# %%
db = DataBlock(blocks = (ImageBlock,CategoryBlock(),CategoryBlock(),CategoryBlock(),
                         RegressionBlock(),RegressionBlock(),RegressionBlock(),RegressionBlock(),
                         RegressionBlock(),RegressionBlock(),RegressionBlock(),RegressionBlock(),
                         RegressionBlock(),RegressionBlock(),RegressionBlock(),RegressionBlock()),
                 get_x=[ColReader('file',pref='wheat_all/'),
                        ColReader('species'),
                        ColReader('water_treatment'),
                        ColReader('management'),
                        ColReader('plot m2'),
                        ColReader('avg_water (L m-2)'),
                        ColReader('N (kg microplot-1)'),
                        ColReader('P (kg microplot-1)'),
                        ColReader('K (kg microplot-1)'),
                        ColReader('avg_height'),
                        ColReader('GA'),
                        ColReader('GGA'),
                        ColReader('CSI'),
                        ColReader('NGRDIveg'),
                        ColReader('TGIveg')
                       ],
                 get_y=[ColReader('final yield (kg)')],
                 splitter=ColSplitter(col='dataset'),    
                 item_tfms = Resize(512),
                 batch_tfms=[*aug_transforms(size=384,flip_vert=True,
                                            max_zoom=1.0), Normalize.from_stats(*imagenet_stats)],
               n_inp=15)
dls = db.dataloaders(dftrain,bs=2)

# %%
from fastai.vision.all import *
callbacks = [
    ShowGraphCallback(),
    # EarlyStoppingCallback(patience=5),
    SaveModelCallback(fname=name+'_all_std'), #convnext_yield_all_minmax
    # ReduceLROnPlateau()
]

# %%
from fastai.metrics import mae,rmse,mse

# %%
class MultiInputModel(Module):
  "A three-headed model given a `body` and `n` output features"
  def __init__(self, body:nn.Sequential):
    nf = num_features_model(nn.Sequential(*body.children()))
    self.body = body
    self.image = create_head(nf, 10)
    self.combine = nn.Sequential(
            nn.Linear(in_features=24, out_features=1, bias=False)
        )
    
    
  
  def forward(self, x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11,x12,x13,x14):
    y = self.body(x0)
    y = self.image(y)
    final_yield = self.combine(torch.cat([y,torch.reshape(x1,(x1.shape[0],1)),
                                     torch.reshape(x2,(x2.shape[0],1)),
                                     torch.reshape(x3,(x3.shape[0],1)),
                                     torch.reshape(x4,(x4.shape[0],1)),
                                     torch.reshape(x5,(x5.shape[0],1)),
                                     torch.reshape(x6,(x6.shape[0],1)),
                                     torch.reshape(x7,(x7.shape[0],1)),
                                     torch.reshape(x8,(x8.shape[0],1)),
                                     torch.reshape(x9,(x9.shape[0],1)),
                                     torch.reshape(x10,(x10.shape[0],1)),
                                     torch.reshape(x11,(x11.shape[0],1)),
                                     torch.reshape(x12,(x12.shape[0],1)),
                                     torch.reshape(x13,(x13.shape[0],1)),
                                     torch.reshape(x14,(x14.shape[0],1))],1))
    return final_yield

# %%
from wwf.vision.timm import *

body = create_timm_body(name, pretrained=True)
# body = create_body(resnet50, pretrained=True)
net = MultiInputModel(body)

# %%
learn = Learner(dls, net, loss_func=MSELossFlat(), metrics=[mae,rmse,mse],cbs=callbacks)

# %%
# learn.lr_find()

# %%
learn.freeze()

# %%
learn.fit_flat_cos(30,lr=1e-3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae</th>
#       <th>_rmse</th>
#       <th>mse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.062681</td>
#       <td>1.101451</td>
#       <td>0.813642</td>
#       <td>1.049500</td>
#       <td>1.101451</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.685861</td>
#       <td>0.529190</td>
#       <td>0.580888</td>
#       <td>0.727455</td>
#       <td>0.529190</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.341743</td>
#       <td>0.357453</td>
#       <td>0.491515</td>
#       <td>0.597874</td>
#       <td>0.357453</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.193324</td>
#       <td>0.126951</td>
#       <td>0.283304</td>
#       <td>0.356302</td>
#       <td>0.126951</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.103152</td>
#       <td>0.064234</td>
#       <td>0.213260</td>
#       <td>0.253444</td>
#       <td>0.064234</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.055241</td>
#       <td>0.054139</td>
#       <td>0.160465</td>
#       <td>0.232678</td>
#       <td>0.054139</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.037694</td>
#       <td>0.036442</td>
#       <td>0.134158</td>
#       <td>0.190898</td>
#       <td>0.036442</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.029719</td>
#       <td>0.010043</td>
#       <td>0.079586</td>
#       <td>0.100216</td>
#       <td>0.010043</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.023216</td>
#       <td>0.026801</td>
#       <td>0.116929</td>
#       <td>0.163709</td>
#       <td>0.026801</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.019357</td>
#       <td>0.011333</td>
#       <td>0.076995</td>
#       <td>0.106458</td>
#       <td>0.011333</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.019478</td>
#       <td>0.011552</td>
#       <td>0.080719</td>
#       <td>0.107482</td>
#       <td>0.011552</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.016810</td>
#       <td>0.008566</td>
#       <td>0.070791</td>
#       <td>0.092555</td>
#       <td>0.008566</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.015335</td>
#       <td>0.009944</td>
#       <td>0.074453</td>
#       <td>0.099719</td>
#       <td>0.009944</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.013825</td>
#       <td>0.005066</td>
#       <td>0.052315</td>
#       <td>0.071177</td>
#       <td>0.005066</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.014258</td>
#       <td>0.005094</td>
#       <td>0.055649</td>
#       <td>0.071372</td>
#       <td>0.005094</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.014081</td>
#       <td>0.005832</td>
#       <td>0.058932</td>
#       <td>0.076368</td>
#       <td>0.005832</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.012680</td>
#       <td>0.003803</td>
#       <td>0.050966</td>
#       <td>0.061667</td>
#       <td>0.003803</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.013283</td>
#       <td>0.002781</td>
#       <td>0.042804</td>
#       <td>0.052735</td>
#       <td>0.002781</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.012388</td>
#       <td>0.002731</td>
#       <td>0.040008</td>
#       <td>0.052264</td>
#       <td>0.002731</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.011642</td>
#       <td>0.001992</td>
#       <td>0.031799</td>
#       <td>0.044629</td>
#       <td>0.001992</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.012414</td>
#       <td>0.005087</td>
#       <td>0.061627</td>
#       <td>0.071326</td>
#       <td>0.005087</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.012209</td>
#       <td>0.003902</td>
#       <td>0.049773</td>
#       <td>0.062465</td>
#       <td>0.003902</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.012516</td>
#       <td>0.002453</td>
#       <td>0.038536</td>
#       <td>0.049528</td>
#       <td>0.002453</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.013081</td>
#       <td>0.002130</td>
#       <td>0.036637</td>
#       <td>0.046151</td>
#       <td>0.002130</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.013024</td>
#       <td>0.003218</td>
#       <td>0.042916</td>
#       <td>0.056730</td>
#       <td>0.003218</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.012012</td>
#       <td>0.002155</td>
#       <td>0.037388</td>
#       <td>0.046421</td>
#       <td>0.002155</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.011598</td>
#       <td>0.003158</td>
#       <td>0.046438</td>
#       <td>0.056201</td>
#       <td>0.003158</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.011610</td>
#       <td>0.003172</td>
#       <td>0.045167</td>
#       <td>0.056325</td>
#       <td>0.003172</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.011278</td>
#       <td>0.003449</td>
#       <td>0.047380</td>
#       <td>0.058730</td>
#       <td>0.003449</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.012083</td>
#       <td>0.003210</td>
#       <td>0.045563</td>
#       <td>0.056655</td>
#       <td>0.003210</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1.10145103931427.
# Better model found at epoch 1 with valid_loss value: 0.5291902422904968.
# Better model found at epoch 2 with valid_loss value: 0.35745346546173096.
# Better model found at epoch 3 with valid_loss value: 0.12695100903511047.
# Better model found at epoch 4 with valid_loss value: 0.06423411518335342.
# Better model found at epoch 5 with valid_loss value: 0.054138943552970886.
# Better model found at epoch 6 with valid_loss value: 0.03644198924303055.
# Better model found at epoch 7 with valid_loss value: 0.010043200105428696.
# Better model found at epoch 11 with valid_loss value: 0.008566339500248432.
# Better model found at epoch 13 with valid_loss value: 0.005066176410764456.
# Better model found at epoch 16 with valid_loss value: 0.0038028431590646505.
# Better model found at epoch 17 with valid_loss value: 0.002780950628221035.
# Better model found at epoch 18 with valid_loss value: 0.0027314808685332537.
# Better model found at epoch 19 with valid_loss value: 0.001991719240322709.

# %%
learn.unfreeze()

# %%
learn.fit_flat_cos(30,lr=1e-4)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae</th>
#       <th>_rmse</th>
#       <th>mse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.011493</td>
#       <td>0.002846</td>
#       <td>0.042070</td>
#       <td>0.053350</td>
#       <td>0.002846</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.011779</td>
#       <td>0.003329</td>
#       <td>0.045661</td>
#       <td>0.057697</td>
#       <td>0.003329</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.011832</td>
#       <td>0.002925</td>
#       <td>0.042397</td>
#       <td>0.054080</td>
#       <td>0.002925</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.012239</td>
#       <td>0.002998</td>
#       <td>0.042728</td>
#       <td>0.054757</td>
#       <td>0.002998</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.011835</td>
#       <td>0.002942</td>
#       <td>0.042619</td>
#       <td>0.054237</td>
#       <td>0.002942</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.011508</td>
#       <td>0.003208</td>
#       <td>0.044125</td>
#       <td>0.056638</td>
#       <td>0.003208</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.011929</td>
#       <td>0.002958</td>
#       <td>0.041846</td>
#       <td>0.054384</td>
#       <td>0.002958</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.012160</td>
#       <td>0.003216</td>
#       <td>0.044423</td>
#       <td>0.056707</td>
#       <td>0.003216</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.011430</td>
#       <td>0.003175</td>
#       <td>0.043763</td>
#       <td>0.056346</td>
#       <td>0.003175</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.011189</td>
#       <td>0.003189</td>
#       <td>0.043811</td>
#       <td>0.056470</td>
#       <td>0.003189</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.011485</td>
#       <td>0.003036</td>
#       <td>0.043433</td>
#       <td>0.055101</td>
#       <td>0.003036</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.011330</td>
#       <td>0.003073</td>
#       <td>0.043252</td>
#       <td>0.055432</td>
#       <td>0.003073</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.011070</td>
#       <td>0.003088</td>
#       <td>0.043863</td>
#       <td>0.055574</td>
#       <td>0.003088</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.011993</td>
#       <td>0.003234</td>
#       <td>0.044516</td>
#       <td>0.056870</td>
#       <td>0.003234</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.011599</td>
#       <td>0.003137</td>
#       <td>0.045007</td>
#       <td>0.056005</td>
#       <td>0.003137</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.011286</td>
#       <td>0.003121</td>
#       <td>0.044402</td>
#       <td>0.055867</td>
#       <td>0.003121</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.011635</td>
#       <td>0.003027</td>
#       <td>0.043278</td>
#       <td>0.055020</td>
#       <td>0.003027</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.011417</td>
#       <td>0.002720</td>
#       <td>0.040700</td>
#       <td>0.052153</td>
#       <td>0.002720</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.011206</td>
#       <td>0.002853</td>
#       <td>0.041554</td>
#       <td>0.053415</td>
#       <td>0.002853</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.012061</td>
#       <td>0.002810</td>
#       <td>0.041944</td>
#       <td>0.053012</td>
#       <td>0.002810</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.011435</td>
#       <td>0.002855</td>
#       <td>0.041487</td>
#       <td>0.053433</td>
#       <td>0.002855</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.011485</td>
#       <td>0.002857</td>
#       <td>0.041866</td>
#       <td>0.053449</td>
#       <td>0.002857</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.011645</td>
#       <td>0.002628</td>
#       <td>0.039543</td>
#       <td>0.051268</td>
#       <td>0.002628</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.011807</td>
#       <td>0.003009</td>
#       <td>0.043194</td>
#       <td>0.054858</td>
#       <td>0.003009</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.011942</td>
#       <td>0.002625</td>
#       <td>0.039551</td>
#       <td>0.051233</td>
#       <td>0.002625</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.011514</td>
#       <td>0.002860</td>
#       <td>0.041600</td>
#       <td>0.053475</td>
#       <td>0.002860</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.011731</td>
#       <td>0.002581</td>
#       <td>0.039104</td>
#       <td>0.050807</td>
#       <td>0.002581</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.010811</td>
#       <td>0.002656</td>
#       <td>0.040019</td>
#       <td>0.051534</td>
#       <td>0.002656</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.011102</td>
#       <td>0.002734</td>
#       <td>0.040433</td>
#       <td>0.052283</td>
#       <td>0.002734</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.011476</td>
#       <td>0.002507</td>
#       <td>0.038361</td>
#       <td>0.050074</td>
#       <td>0.002507</td>
#       <td>00:23</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.0028462226036936045.
# Better model found at epoch 17 with valid_loss value: 0.0027199091855436563.
# Better model found at epoch 22 with valid_loss value: 0.002628413261845708.
# Better model found at epoch 24 with valid_loss value: 0.002624770160764456.
# Better model found at epoch 26 with valid_loss value: 0.0025813127867877483.
# Better model found at epoch 29 with valid_loss value: 0.0025073920842260122.

# %%
dls = db.dataloaders(df,bs=4)

# %%
learn.dls=dls

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
preds,gt = learn.get_preds()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
mean_absolute_error(gt*3.88292+5.30269,preds*3.88292+5.30269)
# Out:
# 0.7587914

# %%
mean_squared_error(gt*3.88292+5.30269,preds*3.88292+5.30269)
# Out:
# 0.85171247

# %%
math.sqrt(mean_squared_error(gt*3.88292+5.30269,preds*3.88292+5.30269))
# Out:
# 0.9228826931339946
