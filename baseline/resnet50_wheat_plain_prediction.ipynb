# %%
from fastai.vision.all import *
import fastai
import timm
import pandas as pd

# %%
import torch
torch.cuda.set_device(1)

# %%
df = pd.read_csv('data/wheat_new.csv',decimal=',')

# %%
df
# Out:
#      Unnamed: 0                 file  DAS  plot nº photo nº species
# 0             0   20220517_1 (1).JPG   96        1     (1).   wheat  \
# 1             1   20220517_1 (2).JPG   96        1     (2).   wheat
# 2             2   20220517_1 (3).JPG   96        1     (3).   wheat
# 3             3   20220517_1 (4).JPG   96        1     (4).   wheat
# 4             4   20220602_1 (1).JPG  112        1     (1).   wheat
# ..          ...                  ...  ...      ...      ...     ...
# 251         251  20220615_25 (4).JPG  125       25     (4).   wheat
# 252         252  20220701_25 (1).JPG  141       25     (1).   wheat
# 253         253  20220701_25 (2).JPG  141       25     (2).   wheat
# 254         254  20220701_25 (3).JPG  141       25     (3).   wheat
# 255         255  20220701_25 (4).JPG  141       25     (4).   wheat
#
#     water_treatment management  plot m2  avg_water (L m-2)  ...
# 0                ww       conv       12          3096.2375  ...  \
# 1                ww       conv       12          3096.2375  ...
# 2                ww       conv       12          3096.2375  ...
# 3                ww       conv       12          3096.2375  ...
# 4                ww       conv       12          3096.2375  ...
# ..              ...        ...      ...                ...  ...
# 251               d       conv       12          2752.8000  ...
# 252               d       conv       12          2752.8000  ...
# 253               d       conv       12          2752.8000  ...
# 254               d       conv       12          2752.8000  ...
# 255               d       conv       12          2752.8000  ...
#
#      P (kg microplot-1)  K (kg microplot-1)  avg_height        GA       GGA
# 0                 0.072               0.072     46.9715  0.959407  0.904393  \
# 1                 0.072               0.072     46.9715  0.963030  0.905523
# 2                 0.072               0.072     46.9715  0.953708  0.898722
# 3                 0.072               0.072     46.9715  0.957117  0.898772
# 4                 0.072               0.072     46.9715  0.892348  0.791199
# ..                  ...                 ...         ...       ...       ...
# 251               0.072               0.072     55.2110  0.788544  0.323428
# 252               0.072               0.072     55.2110  0.031868  0.009072
# 253               0.072               0.072     55.2110  0.025828  0.006849
# 254               0.072               0.072     55.2110  0.022065  0.004773
# 255               0.072               0.072     55.2110  0.026765  0.007124
#
#            CSI  NGRDIveg     TGIveg  final yield (kg)  dataset
# 0     5.734098    0.1324  2569.2709              9.15    train
# 1     5.971505    0.1316  2648.0105              9.15    train
# 2     5.765430    0.1331  2736.4337              9.15    train
# 3     6.095965    0.1267  2550.8238              9.15    train
# 4    11.335180    0.1008  1880.2128              9.15    train
# ..         ...       ...        ...               ...      ...
# 251  58.984136    0.0491  2277.6824              7.95     test
# 252  71.532905    0.0342   946.1760              7.95     test
# 253  73.483356    0.0314   867.4491              7.95     test
# 254  78.367629    0.0196   855.3556              7.95     test
# 255  73.384338    0.0265   979.4368              7.95     test
#
# [256 rows x 21 columns]

# %%
dftrain = df[(df.dataset=='train')|(df.dataset=='validation')]
dftrain.loc[:,'dataset'] =  dftrain['dataset'].apply(lambda x: x=='validation')
df.loc[:,'dataset'] =  df['dataset'].apply(lambda x: x=='test')

# %%
db = DataBlock(blocks = (ImageBlock, RegressionBlock()),
                 get_x=[ColReader('file',pref='wheat_all/')],
                 get_y=[ColReader('final yield (kg)')],
                 splitter=ColSplitter(col='dataset'),    
                 item_tfms = Resize(640),
                 batch_tfms=[*aug_transforms(size=512,flip_vert=True,
                                            max_zoom=1.0), Normalize.from_stats(*imagenet_stats)])
dls = db.dataloaders(dftrain,bs=8)

# %%
dls.show_batch()

# %%
from fastai.vision.all import *
callbacks = [
    ShowGraphCallback(),
    # EarlyStoppingCallback(patience=5),
    SaveModelCallback(fname='resnet50_yield')
]

# %%
from fastai.metrics import mae,rmse,mse

# %%
learn = Learner(dls, timm.create_model('resnet50',num_classes=1,pretrained=True),
                loss_func=MSELossFlat(), metrics=[mae,rmse,mse],cbs=callbacks).to_fp16()
# Out:
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-rsb-weights/resnet50_a1_0-14fe96d1.pth" to /home/joheras/.cache/torch/hub/checkpoints/resnet50_a1_0-14fe96d1.pth

# %%
# learn.lr_find()

# %%
learn.fine_tune(30,base_lr=1e-4)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae</th>
#       <th>_rmse</th>
#       <th>mse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>42.797516</td>
#       <td>50.357929</td>
#       <td>6.133061</td>
#       <td>7.096332</td>
#       <td>50.357929</td>
#       <td>00:30</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 50.35792922973633.
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae</th>
#       <th>_rmse</th>
#       <th>mse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>42.233688</td>
#       <td>49.772324</td>
#       <td>6.089158</td>
#       <td>7.054950</td>
#       <td>49.772324</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>41.849682</td>
#       <td>49.229343</td>
#       <td>6.048448</td>
#       <td>7.016363</td>
#       <td>49.229343</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>41.430843</td>
#       <td>48.532974</td>
#       <td>6.000398</td>
#       <td>6.966561</td>
#       <td>48.532974</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>40.939182</td>
#       <td>47.424072</td>
#       <td>5.919795</td>
#       <td>6.886514</td>
#       <td>47.424072</td>
#       <td>03:59</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>40.290581</td>
#       <td>45.465309</td>
#       <td>5.788844</td>
#       <td>6.742796</td>
#       <td>45.465309</td>
#       <td>05:09</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>38.975292</td>
#       <td>42.346748</td>
#       <td>5.588191</td>
#       <td>6.507438</td>
#       <td>42.346748</td>
#       <td>02:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>37.422661</td>
#       <td>36.880493</td>
#       <td>5.244054</td>
#       <td>6.072931</td>
#       <td>36.880493</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>34.887630</td>
#       <td>27.819897</td>
#       <td>4.637357</td>
#       <td>5.274457</td>
#       <td>27.819897</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>31.230036</td>
#       <td>16.695904</td>
#       <td>3.549731</td>
#       <td>4.086062</td>
#       <td>16.695904</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>26.892958</td>
#       <td>11.396898</td>
#       <td>2.967694</td>
#       <td>3.375929</td>
#       <td>11.396898</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>22.384985</td>
#       <td>7.727304</td>
#       <td>2.422319</td>
#       <td>2.779803</td>
#       <td>7.727304</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>18.535177</td>
#       <td>6.340592</td>
#       <td>2.272169</td>
#       <td>2.518053</td>
#       <td>6.340592</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>15.988328</td>
#       <td>4.862567</td>
#       <td>1.988982</td>
#       <td>2.205123</td>
#       <td>4.862567</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>13.323516</td>
#       <td>7.403645</td>
#       <td>2.587942</td>
#       <td>2.720964</td>
#       <td>7.403645</td>
#       <td>01:50</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>10.891293</td>
#       <td>4.061761</td>
#       <td>1.791955</td>
#       <td>2.015381</td>
#       <td>4.061761</td>
#       <td>02:20</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>9.558604</td>
#       <td>4.370624</td>
#       <td>1.944538</td>
#       <td>2.090604</td>
#       <td>4.370624</td>
#       <td>02:46</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>7.673316</td>
#       <td>4.914531</td>
#       <td>2.063545</td>
#       <td>2.216874</td>
#       <td>4.914531</td>
#       <td>02:16</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>6.461367</td>
#       <td>4.292046</td>
#       <td>1.887713</td>
#       <td>2.071725</td>
#       <td>4.292046</td>
#       <td>03:36</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>6.058753</td>
#       <td>3.988849</td>
#       <td>1.792853</td>
#       <td>1.997210</td>
#       <td>3.988849</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>6.237589</td>
#       <td>4.473764</td>
#       <td>1.938134</td>
#       <td>2.115128</td>
#       <td>4.473764</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>5.801448</td>
#       <td>4.024457</td>
#       <td>1.831520</td>
#       <td>2.006105</td>
#       <td>4.024457</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>5.488182</td>
#       <td>3.912763</td>
#       <td>1.774232</td>
#       <td>1.978070</td>
#       <td>3.912763</td>
#       <td>01:42</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>4.932331</td>
#       <td>3.154623</td>
#       <td>1.587627</td>
#       <td>1.776126</td>
#       <td>3.154623</td>
#       <td>01:39</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>4.296270</td>
#       <td>3.321307</td>
#       <td>1.614345</td>
#       <td>1.822445</td>
#       <td>3.321307</td>
#       <td>02:11</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>4.428610</td>
#       <td>3.070344</td>
#       <td>1.545595</td>
#       <td>1.752240</td>
#       <td>3.070344</td>
#       <td>02:07</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>4.218904</td>
#       <td>3.356447</td>
#       <td>1.624962</td>
#       <td>1.832061</td>
#       <td>3.356447</td>
#       <td>01:53</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>4.052303</td>
#       <td>3.904455</td>
#       <td>1.785313</td>
#       <td>1.975969</td>
#       <td>3.904455</td>
#       <td>02:42</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>4.332501</td>
#       <td>3.753981</td>
#       <td>1.754353</td>
#       <td>1.937519</td>
#       <td>3.753981</td>
#       <td>02:24</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>4.146262</td>
#       <td>3.005589</td>
#       <td>1.520006</td>
#       <td>1.733664</td>
#       <td>3.005589</td>
#       <td>01:13</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>3.731962</td>
#       <td>3.262087</td>
#       <td>1.601361</td>
#       <td>1.806125</td>
#       <td>3.262087</td>
#       <td>01:27</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 49.77232360839844.
# Better model found at epoch 1 with valid_loss value: 49.22934341430664.
# Better model found at epoch 2 with valid_loss value: 48.53297424316406.
# Better model found at epoch 3 with valid_loss value: 47.424072265625.
# Better model found at epoch 4 with valid_loss value: 45.465309143066406.
# Better model found at epoch 5 with valid_loss value: 42.34674835205078.
# Better model found at epoch 6 with valid_loss value: 36.8804931640625.
# Better model found at epoch 7 with valid_loss value: 27.819896697998047.
# Better model found at epoch 8 with valid_loss value: 16.695903778076172.
# Better model found at epoch 9 with valid_loss value: 11.39689826965332.
# Better model found at epoch 10 with valid_loss value: 7.727304458618164.
# Better model found at epoch 11 with valid_loss value: 6.340592384338379.
# Better model found at epoch 12 with valid_loss value: 4.86256742477417.
# Better model found at epoch 14 with valid_loss value: 4.061760902404785.
# Better model found at epoch 18 with valid_loss value: 3.988848924636841.
# Better model found at epoch 21 with valid_loss value: 3.9127631187438965.
# Better model found at epoch 22 with valid_loss value: 3.154622793197632.
# Better model found at epoch 24 with valid_loss value: 3.0703437328338623.
# Better model found at epoch 28 with valid_loss value: 3.005589485168457.

# %%
db = DataBlock(blocks = (ImageBlock, RegressionBlock()),
                 get_x=[ColReader('file',pref='wheat_all/')],
                 get_y=[ColReader('final yield (kg)')],
                 splitter=ColSplitter(col='dataset'),    
                 item_tfms = Resize(640),
                 batch_tfms=[*aug_transforms(size=512,flip_vert=True,
                                            max_zoom=1.0), Normalize.from_stats(*imagenet_stats)])
dls = db.dataloaders(df,bs=8)

# %%
learn.dls=dls

# %%
learn.validate()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Better model found at epoch 0 with valid_loss value: 1.695143222808838.
# (#4) [3.3848211765289307,1.695143222808838,1.8397884368896484,3.3848211765289307]
