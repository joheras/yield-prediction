# %%
from fastai.vision.all import *
import fastai
import timm
import pandas as pd

# %%
import torch
torch.cuda.set_device(1)

# %%
df = pd.read_csv('data/wheat_new.csv',decimal=',')

# %%
df
# Out:
#      Unnamed: 0                 file  DAS  plot nº photo nº species
# 0             0   20220517_1 (1).JPG   96        1     (1).   wheat  \
# 1             1   20220517_1 (2).JPG   96        1     (2).   wheat
# 2             2   20220517_1 (3).JPG   96        1     (3).   wheat
# 3             3   20220517_1 (4).JPG   96        1     (4).   wheat
# 4             4   20220602_1 (1).JPG  112        1     (1).   wheat
# ..          ...                  ...  ...      ...      ...     ...
# 251         251  20220615_25 (4).JPG  125       25     (4).   wheat
# 252         252  20220701_25 (1).JPG  141       25     (1).   wheat
# 253         253  20220701_25 (2).JPG  141       25     (2).   wheat
# 254         254  20220701_25 (3).JPG  141       25     (3).   wheat
# 255         255  20220701_25 (4).JPG  141       25     (4).   wheat
#
#     water_treatment management  plot m2  avg_water (L m-2)  ...
# 0                ww       conv       12          3096.2375  ...  \
# 1                ww       conv       12          3096.2375  ...
# 2                ww       conv       12          3096.2375  ...
# 3                ww       conv       12          3096.2375  ...
# 4                ww       conv       12          3096.2375  ...
# ..              ...        ...      ...                ...  ...
# 251               d       conv       12          2752.8000  ...
# 252               d       conv       12          2752.8000  ...
# 253               d       conv       12          2752.8000  ...
# 254               d       conv       12          2752.8000  ...
# 255               d       conv       12          2752.8000  ...
#
#      P (kg microplot-1)  K (kg microplot-1)  avg_height        GA       GGA
# 0                 0.072               0.072     46.9715  0.959407  0.904393  \
# 1                 0.072               0.072     46.9715  0.963030  0.905523
# 2                 0.072               0.072     46.9715  0.953708  0.898722
# 3                 0.072               0.072     46.9715  0.957117  0.898772
# 4                 0.072               0.072     46.9715  0.892348  0.791199
# ..                  ...                 ...         ...       ...       ...
# 251               0.072               0.072     55.2110  0.788544  0.323428
# 252               0.072               0.072     55.2110  0.031868  0.009072
# 253               0.072               0.072     55.2110  0.025828  0.006849
# 254               0.072               0.072     55.2110  0.022065  0.004773
# 255               0.072               0.072     55.2110  0.026765  0.007124
#
#            CSI  NGRDIveg     TGIveg  final yield (kg)  dataset
# 0     5.734098    0.1324  2569.2709              9.15    train
# 1     5.971505    0.1316  2648.0105              9.15    train
# 2     5.765430    0.1331  2736.4337              9.15    train
# 3     6.095965    0.1267  2550.8238              9.15    train
# 4    11.335180    0.1008  1880.2128              9.15    train
# ..         ...       ...        ...               ...      ...
# 251  58.984136    0.0491  2277.6824              7.95     test
# 252  71.532905    0.0342   946.1760              7.95     test
# 253  73.483356    0.0314   867.4491              7.95     test
# 254  78.367629    0.0196   855.3556              7.95     test
# 255  73.384338    0.0265   979.4368              7.95     test
#
# [256 rows x 21 columns]

# %%
dftrain = df[(df.dataset=='train')|(df.dataset=='validation')]
dftrain.loc[:,'dataset'] =  dftrain['dataset'].apply(lambda x: x=='validation')
df.loc[:,'dataset'] =  df['dataset'].apply(lambda x: x=='test')

# %%
dftrain[dftrain.dataset==False]['final yield (kg)'].describe()
# Out:
# count    160.00000
# mean       5.30269
# std        3.88292
# min        0.85790
# 25%        1.62280
# 50%        5.39235
# 75%        8.75000
# max       10.55000
# Name: final yield (kg), dtype: float64

# %%
dftrain.loc[:,'final yield (kg)'] = dftrain['final yield (kg)'].apply(lambda x : (x - 5.30269)/3.88292)
df.loc[:,'final yield (kg)'] = df['final yield (kg)'].apply(lambda x : (x - 5.30269)/3.88292)

# %%
db = DataBlock(blocks = (ImageBlock, RegressionBlock()),
                 get_x=[ColReader('file',pref='wheat_all/')],
                 get_y=[ColReader('final yield (kg)')],
                 splitter=ColSplitter(col='dataset'),    
                 item_tfms = Resize(640),
                 batch_tfms=[*aug_transforms(size=512, min_scale=0.75,do_flip=True,flip_vert=True,
                  max_rotate=2.,max_zoom=1.1, max_warp=0.05,p_affine=0.9, p_lighting=0.8), 
                         Normalize.from_stats(*imagenet_stats)])
dls = db.dataloaders(dftrain,bs=8)

# %%
dls.show_batch()

# %%
from fastai.vision.all import *
callbacks = [
    ShowGraphCallback(),
    # EarlyStoppingCallback(patience=5),
    SaveModelCallback(fname='efficientnetv2_rw_m_std_yield')
]

# %%
from fastai.metrics import mae,rmse,mse

# %%
learn = Learner(dls, timm.create_model('efficientnetv2_rw_m',num_classes=1,pretrained=True),
                loss_func=MSELossFlat(), metrics=[mae,rmse,mse],cbs=callbacks).to_fp16()

# %%
learn.fine_tune(30,base_lr=3e-3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae</th>
#       <th>_rmse</th>
#       <th>mse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>53.285114</td>
#       <td>1768.199829</td>
#       <td>40.397625</td>
#       <td>42.049965</td>
#       <td>1768.199829</td>
#       <td>00:37</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 1768.1998291015625.
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae</th>
#       <th>_rmse</th>
#       <th>mse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>13.919445</td>
#       <td>3.251326</td>
#       <td>1.344009</td>
#       <td>1.803143</td>
#       <td>3.251326</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6.319731</td>
#       <td>5.447839</td>
#       <td>2.134065</td>
#       <td>2.334061</td>
#       <td>5.447839</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.705926</td>
#       <td>0.773160</td>
#       <td>0.682268</td>
#       <td>0.879295</td>
#       <td>0.773160</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.419508</td>
#       <td>0.597268</td>
#       <td>0.693963</td>
#       <td>0.772831</td>
#       <td>0.597268</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.639406</td>
#       <td>0.313842</td>
#       <td>0.458373</td>
#       <td>0.560216</td>
#       <td>0.313842</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.186476</td>
#       <td>1.439753</td>
#       <td>1.113616</td>
#       <td>1.199897</td>
#       <td>1.439753</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.850308</td>
#       <td>0.104208</td>
#       <td>0.275314</td>
#       <td>0.322812</td>
#       <td>0.104208</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.618587</td>
#       <td>0.151048</td>
#       <td>0.325335</td>
#       <td>0.388649</td>
#       <td>0.151048</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.533085</td>
#       <td>0.093597</td>
#       <td>0.245936</td>
#       <td>0.305936</td>
#       <td>0.093597</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.396115</td>
#       <td>0.128525</td>
#       <td>0.283326</td>
#       <td>0.358504</td>
#       <td>0.128525</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.300405</td>
#       <td>0.459781</td>
#       <td>0.600395</td>
#       <td>0.678072</td>
#       <td>0.459781</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.266193</td>
#       <td>0.084814</td>
#       <td>0.239190</td>
#       <td>0.291228</td>
#       <td>0.084814</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.237262</td>
#       <td>0.487376</td>
#       <td>0.679322</td>
#       <td>0.698123</td>
#       <td>0.487376</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.188292</td>
#       <td>0.107553</td>
#       <td>0.288055</td>
#       <td>0.327953</td>
#       <td>0.107553</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.157494</td>
#       <td>0.071145</td>
#       <td>0.219180</td>
#       <td>0.266731</td>
#       <td>0.071145</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.138071</td>
#       <td>1.166518</td>
#       <td>1.061480</td>
#       <td>1.080055</td>
#       <td>1.166518</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.123287</td>
#       <td>0.134793</td>
#       <td>0.244815</td>
#       <td>0.367142</td>
#       <td>0.134793</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.120089</td>
#       <td>0.264240</td>
#       <td>0.452122</td>
#       <td>0.514043</td>
#       <td>0.264240</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.105097</td>
#       <td>0.048990</td>
#       <td>0.169511</td>
#       <td>0.221337</td>
#       <td>0.048990</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.100183</td>
#       <td>0.129375</td>
#       <td>0.325872</td>
#       <td>0.359687</td>
#       <td>0.129375</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.085527</td>
#       <td>0.501412</td>
#       <td>0.645849</td>
#       <td>0.708104</td>
#       <td>0.501412</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.084905</td>
#       <td>0.038335</td>
#       <td>0.158488</td>
#       <td>0.195793</td>
#       <td>0.038335</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.077427</td>
#       <td>0.572816</td>
#       <td>0.737150</td>
#       <td>0.756846</td>
#       <td>0.572816</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.077650</td>
#       <td>0.171557</td>
#       <td>0.387292</td>
#       <td>0.414194</td>
#       <td>0.171557</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.059134</td>
#       <td>0.029042</td>
#       <td>0.139250</td>
#       <td>0.170416</td>
#       <td>0.029042</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.045986</td>
#       <td>0.050312</td>
#       <td>0.199525</td>
#       <td>0.224304</td>
#       <td>0.050312</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.039929</td>
#       <td>0.101682</td>
#       <td>0.304215</td>
#       <td>0.318877</td>
#       <td>0.101682</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.035512</td>
#       <td>0.059008</td>
#       <td>0.223817</td>
#       <td>0.242916</td>
#       <td>0.059008</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.030407</td>
#       <td>0.054053</td>
#       <td>0.212403</td>
#       <td>0.232494</td>
#       <td>0.054053</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.026440</td>
#       <td>0.046915</td>
#       <td>0.199784</td>
#       <td>0.216598</td>
#       <td>0.046915</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 3.251326322555542.
# Better model found at epoch 2 with valid_loss value: 0.7731596827507019.
# Better model found at epoch 3 with valid_loss value: 0.5972678661346436.
# Better model found at epoch 4 with valid_loss value: 0.3138416111469269.
# Better model found at epoch 6 with valid_loss value: 0.10420791059732437.
# Better model found at epoch 8 with valid_loss value: 0.0935966819524765.
# Better model found at epoch 11 with valid_loss value: 0.08481389284133911.
# Better model found at epoch 14 with valid_loss value: 0.07114523649215698.
# Better model found at epoch 18 with valid_loss value: 0.04899026080965996.
# Better model found at epoch 21 with valid_loss value: 0.03833490237593651.
# Better model found at epoch 24 with valid_loss value: 0.029041729867458344.

# %%
db = DataBlock(blocks = (ImageBlock, RegressionBlock()),
                 get_x=[ColReader('file',pref='wheat_all/')],
                 get_y=[ColReader('final yield (kg)')],
                 splitter=ColSplitter(col='dataset'),    
                 item_tfms = Resize(640),
                 batch_tfms=[*aug_transforms(size=512,flip_vert=True,
                                            max_zoom=1.0), Normalize.from_stats(*imagenet_stats)])
dls = db.dataloaders(df,bs=8)

# %%
learn.dls=dls

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
preds,gt = learn.get_preds()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
mean_absolute_error(gt*3.88292+5.30269,preds*3.88292+5.30269)
# Out:
# 1.0385851

# %%
mean_squared_error(gt*3.88292+5.30269,preds*3.88292+5.30269)
# Out:
# 1.6434356

# %%
math.sqrt(mean_squared_error(gt*3.88292+5.30269,preds*3.88292+5.30269))
# Out:
# 1.2819655211509156
