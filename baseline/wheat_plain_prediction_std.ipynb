# %%
from fastai.vision.all import *
import fastai
import timm
import pandas as pd

# %%
import torch
torch.cuda.set_device(3)

# %%
df = pd.read_csv('data/wheat_new.csv',decimal=',')

# %%
df
# Out:
#      Unnamed: 0                 file  DAS  plot nº photo nº species
# 0             0   20220517_1 (1).JPG   96        1     (1).   wheat  \
# 1             1   20220517_1 (2).JPG   96        1     (2).   wheat
# 2             2   20220517_1 (3).JPG   96        1     (3).   wheat
# 3             3   20220517_1 (4).JPG   96        1     (4).   wheat
# 4             4   20220602_1 (1).JPG  112        1     (1).   wheat
# ..          ...                  ...  ...      ...      ...     ...
# 251         251  20220615_25 (4).JPG  125       25     (4).   wheat
# 252         252  20220701_25 (1).JPG  141       25     (1).   wheat
# 253         253  20220701_25 (2).JPG  141       25     (2).   wheat
# 254         254  20220701_25 (3).JPG  141       25     (3).   wheat
# 255         255  20220701_25 (4).JPG  141       25     (4).   wheat
#
#     water_treatment management  plot m2  avg_water (L m-2)  ...
# 0                ww       conv       12          3096.2375  ...  \
# 1                ww       conv       12          3096.2375  ...
# 2                ww       conv       12          3096.2375  ...
# 3                ww       conv       12          3096.2375  ...
# 4                ww       conv       12          3096.2375  ...
# ..              ...        ...      ...                ...  ...
# 251               d       conv       12          2752.8000  ...
# 252               d       conv       12          2752.8000  ...
# 253               d       conv       12          2752.8000  ...
# 254               d       conv       12          2752.8000  ...
# 255               d       conv       12          2752.8000  ...
#
#      P (kg microplot-1)  K (kg microplot-1)  avg_height        GA       GGA
# 0                 0.072               0.072     46.9715  0.959407  0.904393  \
# 1                 0.072               0.072     46.9715  0.963030  0.905523
# 2                 0.072               0.072     46.9715  0.953708  0.898722
# 3                 0.072               0.072     46.9715  0.957117  0.898772
# 4                 0.072               0.072     46.9715  0.892348  0.791199
# ..                  ...                 ...         ...       ...       ...
# 251               0.072               0.072     55.2110  0.788544  0.323428
# 252               0.072               0.072     55.2110  0.031868  0.009072
# 253               0.072               0.072     55.2110  0.025828  0.006849
# 254               0.072               0.072     55.2110  0.022065  0.004773
# 255               0.072               0.072     55.2110  0.026765  0.007124
#
#            CSI  NGRDIveg     TGIveg  final yield (kg)  dataset
# 0     5.734098    0.1324  2569.2709              9.15    train
# 1     5.971505    0.1316  2648.0105              9.15    train
# 2     5.765430    0.1331  2736.4337              9.15    train
# 3     6.095965    0.1267  2550.8238              9.15    train
# 4    11.335180    0.1008  1880.2128              9.15    train
# ..         ...       ...        ...               ...      ...
# 251  58.984136    0.0491  2277.6824              7.95     test
# 252  71.532905    0.0342   946.1760              7.95     test
# 253  73.483356    0.0314   867.4491              7.95     test
# 254  78.367629    0.0196   855.3556              7.95     test
# 255  73.384338    0.0265   979.4368              7.95     test
#
# [256 rows x 21 columns]

# %%
dftrain = df[(df.dataset=='train')|(df.dataset=='validation')]
dftrain.loc[:,'dataset'] =  dftrain['dataset'].apply(lambda x: x=='validation')
df.loc[:,'dataset'] =  df['dataset'].apply(lambda x: x=='test')

# %%
dftrain[dftrain.dataset==False]['final yield (kg)'].describe()
# Out:
# count    160.00000
# mean       5.30269
# std        3.88292
# min        0.85790
# 25%        1.62280
# 50%        5.39235
# 75%        8.75000
# max       10.55000
# Name: final yield (kg), dtype: float64

# %%
dftrain.loc[:,'final yield (kg)'] = dftrain['final yield (kg)'].apply(lambda x : (x - 5.30269)/3.88292)
df.loc[:,'final yield (kg)'] = df['final yield (kg)'].apply(lambda x : (x - 5.30269)/3.88292)

# %%
db = DataBlock(blocks = (ImageBlock, RegressionBlock()),
                 get_x=[ColReader('file',pref='wheat_all/')],
                 get_y=[ColReader('final yield (kg)')],
                 splitter=ColSplitter(col='dataset'),    
                 item_tfms = Resize(640),
                 batch_tfms=[*aug_transforms(size=512,flip_vert=True,
                                            max_zoom=1.0), Normalize.from_stats(*imagenet_stats)])
dls = db.dataloaders(dftrain,bs=8)

# %%
dls.show_batch()

# %%
from fastai.vision.all import *
callbacks = [
    ShowGraphCallback(),
    # EarlyStoppingCallback(patience=5),
    SaveModelCallback(fname='convnext_yield')
]

# %%
from fastai.metrics import mae,rmse,mse

# %%
learn = Learner(dls, timm.create_model('convnext_base',num_classes=1,pretrained=True),
                loss_func=MSELossFlat(), metrics=[mae,rmse,mse],cbs=callbacks).to_fp16()

# %%
# learn.lr_find()

# %%
learn.fine_tune(30,base_lr=1e-4)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae</th>
#       <th>_rmse</th>
#       <th>mse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.415927</td>
#       <td>0.034190</td>
#       <td>0.161579</td>
#       <td>0.184907</td>
#       <td>0.034190</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.034190453588962555.
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae</th>
#       <th>_rmse</th>
#       <th>mse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.036795</td>
#       <td>0.052843</td>
#       <td>0.189030</td>
#       <td>0.229876</td>
#       <td>0.052843</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.034450</td>
#       <td>0.040256</td>
#       <td>0.160482</td>
#       <td>0.200639</td>
#       <td>0.040256</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.030762</td>
#       <td>0.042024</td>
#       <td>0.190223</td>
#       <td>0.204997</td>
#       <td>0.042024</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.027220</td>
#       <td>0.045084</td>
#       <td>0.180029</td>
#       <td>0.212330</td>
#       <td>0.045084</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.025185</td>
#       <td>0.050097</td>
#       <td>0.203895</td>
#       <td>0.223824</td>
#       <td>0.050097</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.023931</td>
#       <td>0.042788</td>
#       <td>0.190155</td>
#       <td>0.206852</td>
#       <td>0.042788</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.024661</td>
#       <td>0.028466</td>
#       <td>0.143676</td>
#       <td>0.168720</td>
#       <td>0.028466</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.023900</td>
#       <td>0.031214</td>
#       <td>0.146642</td>
#       <td>0.176675</td>
#       <td>0.031214</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.023424</td>
#       <td>0.027069</td>
#       <td>0.146137</td>
#       <td>0.164528</td>
#       <td>0.027069</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.022402</td>
#       <td>0.028802</td>
#       <td>0.147211</td>
#       <td>0.169711</td>
#       <td>0.028802</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.021363</td>
#       <td>0.046653</td>
#       <td>0.178737</td>
#       <td>0.215993</td>
#       <td>0.046653</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.020522</td>
#       <td>0.038545</td>
#       <td>0.172162</td>
#       <td>0.196329</td>
#       <td>0.038545</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.019605</td>
#       <td>0.038257</td>
#       <td>0.184074</td>
#       <td>0.195594</td>
#       <td>0.038257</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.018659</td>
#       <td>0.025493</td>
#       <td>0.145544</td>
#       <td>0.159665</td>
#       <td>0.025493</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.017437</td>
#       <td>0.044459</td>
#       <td>0.173080</td>
#       <td>0.210854</td>
#       <td>0.044459</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.017652</td>
#       <td>0.036219</td>
#       <td>0.177856</td>
#       <td>0.190314</td>
#       <td>0.036219</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.016985</td>
#       <td>0.026244</td>
#       <td>0.140493</td>
#       <td>0.161999</td>
#       <td>0.026244</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.015161</td>
#       <td>0.038781</td>
#       <td>0.174291</td>
#       <td>0.196929</td>
#       <td>0.038781</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.014749</td>
#       <td>0.015321</td>
#       <td>0.106643</td>
#       <td>0.123777</td>
#       <td>0.015321</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.012915</td>
#       <td>0.021432</td>
#       <td>0.131001</td>
#       <td>0.146397</td>
#       <td>0.021432</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.011436</td>
#       <td>0.019813</td>
#       <td>0.114647</td>
#       <td>0.140760</td>
#       <td>0.019813</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.010467</td>
#       <td>0.020173</td>
#       <td>0.117089</td>
#       <td>0.142031</td>
#       <td>0.020173</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.010030</td>
#       <td>0.026643</td>
#       <td>0.136231</td>
#       <td>0.163227</td>
#       <td>0.026643</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.009274</td>
#       <td>0.022761</td>
#       <td>0.126652</td>
#       <td>0.150868</td>
#       <td>0.022761</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.008618</td>
#       <td>0.021774</td>
#       <td>0.122851</td>
#       <td>0.147560</td>
#       <td>0.021774</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.007907</td>
#       <td>0.019827</td>
#       <td>0.117432</td>
#       <td>0.140808</td>
#       <td>0.019827</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.007619</td>
#       <td>0.021427</td>
#       <td>0.120666</td>
#       <td>0.146378</td>
#       <td>0.021427</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.007286</td>
#       <td>0.020689</td>
#       <td>0.119628</td>
#       <td>0.143838</td>
#       <td>0.020689</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.006973</td>
#       <td>0.021179</td>
#       <td>0.121355</td>
#       <td>0.145531</td>
#       <td>0.021179</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.006665</td>
#       <td>0.021186</td>
#       <td>0.121447</td>
#       <td>0.145554</td>
#       <td>0.021186</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.052842821925878525.
# Better model found at epoch 1 with valid_loss value: 0.04025598615407944.
# Better model found at epoch 6 with valid_loss value: 0.02846631407737732.
# Better model found at epoch 8 with valid_loss value: 0.027069441974163055.
# Better model found at epoch 13 with valid_loss value: 0.02549278363585472.
# Better model found at epoch 18 with valid_loss value: 0.015320689417421818.

# %%
db = DataBlock(blocks = (ImageBlock, RegressionBlock()),
                 get_x=[ColReader('file',pref='wheat_all/')],
                 get_y=[ColReader('final yield (kg)')],
                 splitter=ColSplitter(col='dataset'),    
                 item_tfms = Resize(640),
                 batch_tfms=[*aug_transforms(size=512,flip_vert=True,
                                            max_zoom=1.0), Normalize.from_stats(*imagenet_stats)])
dls = db.dataloaders(df,bs=8)

# %%
learn.dls=dls

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
preds,gt = learn.get_preds()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
mean_absolute_error(gt*3.88292+5.30269,preds*3.88292+5.30269)
# Out:
# 0.900278

# %%
mean_squared_error(gt*3.88292+5.30269,preds*3.88292+5.30269)
# Out:
# 1.1945311

# %%
math.sqrt(mean_squared_error(gt*3.88292+5.30269,preds*3.88292+5.30269))
# Out:
# 1.0929460568147884
