# %%
from fastai.vision.all import *
import fastai
import timm
import pandas as pd

# %%
import torch
torch.cuda.set_device(0)

# %%
df = pd.read_csv('data/wheat_new.csv',decimal=',')

# %%
df
# Out:
#      Unnamed: 0                 file  DAS  plot nº photo nº species
# 0             0   20220517_1 (1).JPG   96        1     (1).   wheat  \
# 1             1   20220517_1 (2).JPG   96        1     (2).   wheat
# 2             2   20220517_1 (3).JPG   96        1     (3).   wheat
# 3             3   20220517_1 (4).JPG   96        1     (4).   wheat
# 4             4   20220602_1 (1).JPG  112        1     (1).   wheat
# ..          ...                  ...  ...      ...      ...     ...
# 251         251  20220615_25 (4).JPG  125       25     (4).   wheat
# 252         252  20220701_25 (1).JPG  141       25     (1).   wheat
# 253         253  20220701_25 (2).JPG  141       25     (2).   wheat
# 254         254  20220701_25 (3).JPG  141       25     (3).   wheat
# 255         255  20220701_25 (4).JPG  141       25     (4).   wheat
#
#     water_treatment management  plot m2  avg_water (L m-2)  ...
# 0                ww       conv       12          3096.2375  ...  \
# 1                ww       conv       12          3096.2375  ...
# 2                ww       conv       12          3096.2375  ...
# 3                ww       conv       12          3096.2375  ...
# 4                ww       conv       12          3096.2375  ...
# ..              ...        ...      ...                ...  ...
# 251               d       conv       12          2752.8000  ...
# 252               d       conv       12          2752.8000  ...
# 253               d       conv       12          2752.8000  ...
# 254               d       conv       12          2752.8000  ...
# 255               d       conv       12          2752.8000  ...
#
#      P (kg microplot-1)  K (kg microplot-1)  avg_height        GA       GGA
# 0                 0.072               0.072     46.9715  0.959407  0.904393  \
# 1                 0.072               0.072     46.9715  0.963030  0.905523
# 2                 0.072               0.072     46.9715  0.953708  0.898722
# 3                 0.072               0.072     46.9715  0.957117  0.898772
# 4                 0.072               0.072     46.9715  0.892348  0.791199
# ..                  ...                 ...         ...       ...       ...
# 251               0.072               0.072     55.2110  0.788544  0.323428
# 252               0.072               0.072     55.2110  0.031868  0.009072
# 253               0.072               0.072     55.2110  0.025828  0.006849
# 254               0.072               0.072     55.2110  0.022065  0.004773
# 255               0.072               0.072     55.2110  0.026765  0.007124
#
#            CSI  NGRDIveg     TGIveg  final yield (kg)  dataset
# 0     5.734098    0.1324  2569.2709              9.15    train
# 1     5.971505    0.1316  2648.0105              9.15    train
# 2     5.765430    0.1331  2736.4337              9.15    train
# 3     6.095965    0.1267  2550.8238              9.15    train
# 4    11.335180    0.1008  1880.2128              9.15    train
# ..         ...       ...        ...               ...      ...
# 251  58.984136    0.0491  2277.6824              7.95     test
# 252  71.532905    0.0342   946.1760              7.95     test
# 253  73.483356    0.0314   867.4491              7.95     test
# 254  78.367629    0.0196   855.3556              7.95     test
# 255  73.384338    0.0265   979.4368              7.95     test
#
# [256 rows x 21 columns]

# %%
dftrain = df[(df.dataset=='train')|(df.dataset=='validation')]
dftrain.loc[:,'dataset'] =  dftrain['dataset'].apply(lambda x: x=='validation')
df.loc[:,'dataset'] =  df['dataset'].apply(lambda x: x=='test')

# %%
dftrain[dftrain.dataset==False]['final yield (kg)'].describe()
# Out:
# count    160.00000
# mean       5.30269
# std        3.88292
# min        0.85790
# 25%        1.62280
# 50%        5.39235
# 75%        8.75000
# max       10.55000
# Name: final yield (kg), dtype: float64

# %%
dftrain.loc[:,'final yield (kg)'] = dftrain['final yield (kg)'].apply(lambda x : (x - 5.30269)/3.88292)
df.loc[:,'final yield (kg)'] = df['final yield (kg)'].apply(lambda x : (x - 5.30269)/3.88292)

# %%
db = DataBlock(blocks = (ImageBlock, RegressionBlock()),
                 get_x=[ColReader('file',pref='wheat_all/')],
                 get_y=[ColReader('final yield (kg)')],
                 splitter=ColSplitter(col='dataset'),    
                 item_tfms = Resize(512),
                 batch_tfms=[*aug_transforms(size=384,flip_vert=True,
                                            max_zoom=1.0), Normalize.from_stats(*imagenet_stats)])
dls = db.dataloaders(dftrain,bs=8)

# %%
dls.show_batch()

# %%
from fastai.vision.all import *
callbacks = [
    ShowGraphCallback(),
    # EarlyStoppingCallback(patience=5),
    SaveModelCallback(fname='volo_std_yield')
]

# %%
from fastai.metrics import mae,rmse,mse

# %%
learn = Learner(dls, timm.create_model('vit_base_patch16_384',num_classes=1,pretrained=True),
                loss_func=MSELossFlat(), metrics=[mae,rmse,mse],cbs=callbacks).to_fp16()

# %%
# learn.lr_find()

# %%
learn.fine_tune(30,base_lr=1e-4)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae</th>
#       <th>_rmse</th>
#       <th>mse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.046236</td>
#       <td>0.871114</td>
#       <td>0.781241</td>
#       <td>0.933335</td>
#       <td>0.871114</td>
#       <td>00:35</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.8711143732070923.
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae</th>
#       <th>_rmse</th>
#       <th>mse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.412007</td>
#       <td>0.047316</td>
#       <td>0.169924</td>
#       <td>0.217523</td>
#       <td>0.047316</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.213232</td>
#       <td>0.029386</td>
#       <td>0.146787</td>
#       <td>0.171424</td>
#       <td>0.029386</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.215035</td>
#       <td>0.040537</td>
#       <td>0.162944</td>
#       <td>0.201338</td>
#       <td>0.040537</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.146579</td>
#       <td>0.042817</td>
#       <td>0.182969</td>
#       <td>0.206923</td>
#       <td>0.042817</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.112201</td>
#       <td>0.066382</td>
#       <td>0.218540</td>
#       <td>0.257646</td>
#       <td>0.066382</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.099794</td>
#       <td>0.036300</td>
#       <td>0.154620</td>
#       <td>0.190525</td>
#       <td>0.036300</td>
#       <td>00:40</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.104490</td>
#       <td>0.020070</td>
#       <td>0.115615</td>
#       <td>0.141669</td>
#       <td>0.020070</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.088771</td>
#       <td>0.203310</td>
#       <td>0.386806</td>
#       <td>0.450899</td>
#       <td>0.203310</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.090452</td>
#       <td>0.013566</td>
#       <td>0.101998</td>
#       <td>0.116473</td>
#       <td>0.013566</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.080111</td>
#       <td>0.076658</td>
#       <td>0.263627</td>
#       <td>0.276872</td>
#       <td>0.076658</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.064599</td>
#       <td>0.097508</td>
#       <td>0.305726</td>
#       <td>0.312262</td>
#       <td>0.097508</td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.053868</td>
#       <td>0.046077</td>
#       <td>0.184155</td>
#       <td>0.214656</td>
#       <td>0.046077</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.049817</td>
#       <td>0.035972</td>
#       <td>0.173123</td>
#       <td>0.189664</td>
#       <td>0.035972</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.046872</td>
#       <td>0.009381</td>
#       <td>0.078257</td>
#       <td>0.096854</td>
#       <td>0.009381</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.041118</td>
#       <td>0.007287</td>
#       <td>0.071491</td>
#       <td>0.085362</td>
#       <td>0.007287</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.034776</td>
#       <td>0.056233</td>
#       <td>0.221969</td>
#       <td>0.237135</td>
#       <td>0.056233</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.030412</td>
#       <td>0.027580</td>
#       <td>0.128688</td>
#       <td>0.166072</td>
#       <td>0.027580</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.029482</td>
#       <td>0.151340</td>
#       <td>0.383866</td>
#       <td>0.389024</td>
#       <td>0.151340</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.039389</td>
#       <td>0.121779</td>
#       <td>0.299058</td>
#       <td>0.348968</td>
#       <td>0.121779</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.035456</td>
#       <td>0.055677</td>
#       <td>0.208785</td>
#       <td>0.235961</td>
#       <td>0.055677</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.030455</td>
#       <td>0.011684</td>
#       <td>0.084636</td>
#       <td>0.108094</td>
#       <td>0.011684</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.026586</td>
#       <td>0.016543</td>
#       <td>0.109002</td>
#       <td>0.128618</td>
#       <td>0.016543</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.022291</td>
#       <td>0.012609</td>
#       <td>0.091675</td>
#       <td>0.112289</td>
#       <td>0.012609</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.020110</td>
#       <td>0.030977</td>
#       <td>0.156064</td>
#       <td>0.176002</td>
#       <td>0.030977</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.017155</td>
#       <td>0.023221</td>
#       <td>0.128092</td>
#       <td>0.152384</td>
#       <td>0.023221</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.015071</td>
#       <td>0.026909</td>
#       <td>0.138986</td>
#       <td>0.164039</td>
#       <td>0.026909</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.012954</td>
#       <td>0.034339</td>
#       <td>0.158290</td>
#       <td>0.185309</td>
#       <td>0.034339</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.011739</td>
#       <td>0.024221</td>
#       <td>0.126578</td>
#       <td>0.155629</td>
#       <td>0.024221</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.011370</td>
#       <td>0.028008</td>
#       <td>0.138834</td>
#       <td>0.167355</td>
#       <td>0.028008</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.010642</td>
#       <td>0.026640</td>
#       <td>0.134470</td>
#       <td>0.163218</td>
#       <td>0.026640</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.04731614142656326.
# Better model found at epoch 1 with valid_loss value: 0.029386216774582863.
# Better model found at epoch 6 with valid_loss value: 0.020070161670446396.
# Better model found at epoch 8 with valid_loss value: 0.013565903529524803.
# Better model found at epoch 13 with valid_loss value: 0.00938066840171814.
# Better model found at epoch 14 with valid_loss value: 0.0072867549024522305.

# %%
db = DataBlock(blocks = (ImageBlock, RegressionBlock()),
                 get_x=[ColReader('file',pref='wheat_all/')],
                 get_y=[ColReader('final yield (kg)')],
                 splitter=ColSplitter(col='dataset'),    
                 item_tfms = Resize(512),
                 batch_tfms=[*aug_transforms(size=384,flip_vert=True,
                                            max_zoom=1.0), Normalize.from_stats(*imagenet_stats)])
dls = db.dataloaders(df,bs=8)

# %%
learn.dls=dls

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
preds,gt = learn.get_preds()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
mean_absolute_error(gt*3.88292+5.30269,preds*3.88292+5.30269)
# Out:
# 0.9777668

# %%
mean_squared_error(gt*3.88292+5.30269,preds*3.88292+5.30269)
# Out:
# 1.4100419

# %%
math.sqrt(mean_squared_error(gt*3.88292+5.30269,preds*3.88292+5.30269))
# Out:
# 1.1874518635680862
