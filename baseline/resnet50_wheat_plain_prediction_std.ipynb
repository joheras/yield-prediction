# %%
from fastai.vision.all import *
import fastai
import timm
import pandas as pd

# %%
import torch
torch.cuda.set_device(3)

# %%
df = pd.read_csv('data/wheat_new.csv',decimal=',')

# %%
df
# Out:
#      Unnamed: 0                 file  DAS  plot nº photo nº species
# 0             0   20220517_1 (1).JPG   96        1     (1).   wheat  \
# 1             1   20220517_1 (2).JPG   96        1     (2).   wheat
# 2             2   20220517_1 (3).JPG   96        1     (3).   wheat
# 3             3   20220517_1 (4).JPG   96        1     (4).   wheat
# 4             4   20220602_1 (1).JPG  112        1     (1).   wheat
# ..          ...                  ...  ...      ...      ...     ...
# 251         251  20220615_25 (4).JPG  125       25     (4).   wheat
# 252         252  20220701_25 (1).JPG  141       25     (1).   wheat
# 253         253  20220701_25 (2).JPG  141       25     (2).   wheat
# 254         254  20220701_25 (3).JPG  141       25     (3).   wheat
# 255         255  20220701_25 (4).JPG  141       25     (4).   wheat
#
#     water_treatment management  plot m2  avg_water (L m-2)  ...
# 0                ww       conv       12          3096.2375  ...  \
# 1                ww       conv       12          3096.2375  ...
# 2                ww       conv       12          3096.2375  ...
# 3                ww       conv       12          3096.2375  ...
# 4                ww       conv       12          3096.2375  ...
# ..              ...        ...      ...                ...  ...
# 251               d       conv       12          2752.8000  ...
# 252               d       conv       12          2752.8000  ...
# 253               d       conv       12          2752.8000  ...
# 254               d       conv       12          2752.8000  ...
# 255               d       conv       12          2752.8000  ...
#
#      P (kg microplot-1)  K (kg microplot-1)  avg_height        GA       GGA
# 0                 0.072               0.072     46.9715  0.959407  0.904393  \
# 1                 0.072               0.072     46.9715  0.963030  0.905523
# 2                 0.072               0.072     46.9715  0.953708  0.898722
# 3                 0.072               0.072     46.9715  0.957117  0.898772
# 4                 0.072               0.072     46.9715  0.892348  0.791199
# ..                  ...                 ...         ...       ...       ...
# 251               0.072               0.072     55.2110  0.788544  0.323428
# 252               0.072               0.072     55.2110  0.031868  0.009072
# 253               0.072               0.072     55.2110  0.025828  0.006849
# 254               0.072               0.072     55.2110  0.022065  0.004773
# 255               0.072               0.072     55.2110  0.026765  0.007124
#
#            CSI  NGRDIveg     TGIveg  final yield (kg)  dataset
# 0     5.734098    0.1324  2569.2709              9.15    train
# 1     5.971505    0.1316  2648.0105              9.15    train
# 2     5.765430    0.1331  2736.4337              9.15    train
# 3     6.095965    0.1267  2550.8238              9.15    train
# 4    11.335180    0.1008  1880.2128              9.15    train
# ..         ...       ...        ...               ...      ...
# 251  58.984136    0.0491  2277.6824              7.95     test
# 252  71.532905    0.0342   946.1760              7.95     test
# 253  73.483356    0.0314   867.4491              7.95     test
# 254  78.367629    0.0196   855.3556              7.95     test
# 255  73.384338    0.0265   979.4368              7.95     test
#
# [256 rows x 21 columns]

# %%
dftrain = df[(df.dataset=='train')|(df.dataset=='validation')]
dftrain.loc[:,'dataset'] =  dftrain['dataset'].apply(lambda x: x=='validation')
df.loc[:,'dataset'] =  df['dataset'].apply(lambda x: x=='test')

# %%
dftrain[dftrain.dataset==False]['final yield (kg)'].describe()
# Out:
# count    160.00000
# mean       5.30269
# std        3.88292
# min        0.85790
# 25%        1.62280
# 50%        5.39235
# 75%        8.75000
# max       10.55000
# Name: final yield (kg), dtype: float64

# %%
dftrain.loc[:,'final yield (kg)'] = dftrain['final yield (kg)'].apply(lambda x : (x - 5.30269)/3.88292)
df.loc[:,'final yield (kg)'] = df['final yield (kg)'].apply(lambda x : (x - 5.30269)/3.88292)

# %%
db = DataBlock(blocks = (ImageBlock, RegressionBlock()),
                 get_x=[ColReader('file',pref='wheat_all/')],
                 get_y=[ColReader('final yield (kg)')],
                 splitter=ColSplitter(col='dataset'),    
                 item_tfms = Resize(640),
                 batch_tfms=[*aug_transforms(size=512,flip_vert=True,
                                            max_zoom=1.0), Normalize.from_stats(*imagenet_stats)])
dls = db.dataloaders(dftrain,bs=8)

# %%
dls.show_batch()

# %%
from fastai.vision.all import *
callbacks = [
    ShowGraphCallback(),
    # EarlyStoppingCallback(patience=5),
    SaveModelCallback(fname='resnet50_std_yield')
]

# %%
from fastai.metrics import mae,rmse,mse

# %%
learn = Learner(dls, timm.create_model('resnet50',num_classes=1,pretrained=True),
                loss_func=MSELossFlat(), metrics=[mae,rmse,mse],cbs=callbacks).to_fp16()

# %%
# learn.lr_find()

# %%
learn.fine_tune(30,base_lr=1e-4)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae</th>
#       <th>_rmse</th>
#       <th>mse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.982872</td>
#       <td>0.871241</td>
#       <td>0.908238</td>
#       <td>0.933403</td>
#       <td>0.871241</td>
#       <td>00:23</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.8712407350540161.
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>mae</th>
#       <th>_rmse</th>
#       <th>mse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.939049</td>
#       <td>0.841143</td>
#       <td>0.887845</td>
#       <td>0.917138</td>
#       <td>0.841143</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.934286</td>
#       <td>0.819668</td>
#       <td>0.877779</td>
#       <td>0.905355</td>
#       <td>0.819668</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.924324</td>
#       <td>0.793497</td>
#       <td>0.864024</td>
#       <td>0.890784</td>
#       <td>0.793497</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.904267</td>
#       <td>0.759101</td>
#       <td>0.845665</td>
#       <td>0.871264</td>
#       <td>0.759101</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.877817</td>
#       <td>0.707386</td>
#       <td>0.815822</td>
#       <td>0.841063</td>
#       <td>0.707386</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.846721</td>
#       <td>0.639227</td>
#       <td>0.773345</td>
#       <td>0.799517</td>
#       <td>0.639227</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.798696</td>
#       <td>0.556450</td>
#       <td>0.708611</td>
#       <td>0.745956</td>
#       <td>0.556450</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.733101</td>
#       <td>0.447391</td>
#       <td>0.616255</td>
#       <td>0.668873</td>
#       <td>0.447391</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.660631</td>
#       <td>0.321605</td>
#       <td>0.509703</td>
#       <td>0.567102</td>
#       <td>0.321605</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.570578</td>
#       <td>0.236044</td>
#       <td>0.392865</td>
#       <td>0.485844</td>
#       <td>0.236044</td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.487339</td>
#       <td>0.195501</td>
#       <td>0.372390</td>
#       <td>0.442155</td>
#       <td>0.195501</td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.402948</td>
#       <td>0.115342</td>
#       <td>0.294188</td>
#       <td>0.339620</td>
#       <td>0.115342</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.342910</td>
#       <td>0.085557</td>
#       <td>0.255332</td>
#       <td>0.292502</td>
#       <td>0.085557</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.290643</td>
#       <td>0.082429</td>
#       <td>0.256882</td>
#       <td>0.287104</td>
#       <td>0.082429</td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.249606</td>
#       <td>0.049296</td>
#       <td>0.192939</td>
#       <td>0.222027</td>
#       <td>0.049296</td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.216042</td>
#       <td>0.049773</td>
#       <td>0.193695</td>
#       <td>0.223099</td>
#       <td>0.049773</td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.209834</td>
#       <td>0.044231</td>
#       <td>0.183242</td>
#       <td>0.210311</td>
#       <td>0.044231</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.207243</td>
#       <td>0.037933</td>
#       <td>0.166770</td>
#       <td>0.194764</td>
#       <td>0.037933</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.218906</td>
#       <td>0.027394</td>
#       <td>0.127494</td>
#       <td>0.165511</td>
#       <td>0.027394</td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.204309</td>
#       <td>0.041162</td>
#       <td>0.162954</td>
#       <td>0.202884</td>
#       <td>0.041162</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.189792</td>
#       <td>0.028833</td>
#       <td>0.138224</td>
#       <td>0.169804</td>
#       <td>0.028833</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.154204</td>
#       <td>0.031789</td>
#       <td>0.151365</td>
#       <td>0.178296</td>
#       <td>0.031789</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.152887</td>
#       <td>0.027732</td>
#       <td>0.126670</td>
#       <td>0.166530</td>
#       <td>0.027732</td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.149256</td>
#       <td>0.040276</td>
#       <td>0.174368</td>
#       <td>0.200689</td>
#       <td>0.040276</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.149104</td>
#       <td>0.049059</td>
#       <td>0.181923</td>
#       <td>0.221492</td>
#       <td>0.049059</td>
#       <td>00:29</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.150493</td>
#       <td>0.033851</td>
#       <td>0.137937</td>
#       <td>0.183987</td>
#       <td>0.033851</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.147814</td>
#       <td>0.029838</td>
#       <td>0.130956</td>
#       <td>0.172735</td>
#       <td>0.029838</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.127789</td>
#       <td>0.027838</td>
#       <td>0.129981</td>
#       <td>0.166848</td>
#       <td>0.027838</td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.169706</td>
#       <td>0.033468</td>
#       <td>0.139727</td>
#       <td>0.182943</td>
#       <td>0.033468</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.164840</td>
#       <td>0.026068</td>
#       <td>0.123558</td>
#       <td>0.161457</td>
#       <td>0.026068</td>
#       <td>00:32</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.8411425352096558.
# Better model found at epoch 1 with valid_loss value: 0.8196684122085571.
# Better model found at epoch 2 with valid_loss value: 0.7934965491294861.
# Better model found at epoch 3 with valid_loss value: 0.7591012120246887.
# Better model found at epoch 4 with valid_loss value: 0.7073861360549927.
# Better model found at epoch 5 with valid_loss value: 0.6392272710800171.
# Better model found at epoch 6 with valid_loss value: 0.5564500093460083.
# Better model found at epoch 7 with valid_loss value: 0.4473910629749298.
# Better model found at epoch 8 with valid_loss value: 0.32160478830337524.
# Better model found at epoch 9 with valid_loss value: 0.23604439198970795.
# Better model found at epoch 10 with valid_loss value: 0.1955014169216156.
# Better model found at epoch 11 with valid_loss value: 0.1153416782617569.
# Better model found at epoch 12 with valid_loss value: 0.0855572447180748.
# Better model found at epoch 13 with valid_loss value: 0.08242897689342499.
# Better model found at epoch 14 with valid_loss value: 0.0492960587143898.
# Better model found at epoch 16 with valid_loss value: 0.04423089697957039.
# Better model found at epoch 17 with valid_loss value: 0.0379328727722168.
# Better model found at epoch 18 with valid_loss value: 0.027393784373998642.
# Better model found at epoch 29 with valid_loss value: 0.026068227365612984.

# %%
db = DataBlock(blocks = (ImageBlock, RegressionBlock()),
                 get_x=[ColReader('file',pref='wheat_all/')],
                 get_y=[ColReader('final yield (kg)')],
                 splitter=ColSplitter(col='dataset'),    
                 item_tfms = Resize(512),
                 batch_tfms=[*aug_transforms(size=384,flip_vert=True,
                                            max_zoom=1.0), Normalize.from_stats(*imagenet_stats)])
dls = db.dataloaders(df,bs=8)

# %%
learn.dls=dls

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
preds,gt = learn.get_preds()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
mean_absolute_error(gt*3.88292+5.30269,preds*3.88292+5.30269)
# Out:
# 1.2048452

# %%
mean_squared_error(gt*3.88292+5.30269,preds*3.88292+5.30269)
# Out:
# 1.9743454

# %%
math.sqrt(mean_squared_error(gt*3.88292+5.30269,preds*3.88292+5.30269))
# Out:
# 1.4051140329642056
