# %%
from fastai.vision.all import *
import fastai
import timm
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
# Out:
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")

# %%
import torch
torch.cuda.set_device(1)

# %%
df = pd.read_csv('data/wheat_new.csv',decimal=',')

# %%
name = 'vit_base_patch16_384'

# %%
df
# Out:
#      Unnamed: 0                 file  DAS  plot nº photo nº species  \
# 0             0   20220517_1 (1).JPG   96        1     (1).   wheat
# 1             1   20220517_1 (2).JPG   96        1     (2).   wheat
# 2             2   20220517_1 (3).JPG   96        1     (3).   wheat
# 3             3   20220517_1 (4).JPG   96        1     (4).   wheat
# 4             4   20220602_1 (1).JPG  112        1     (1).   wheat
# ..          ...                  ...  ...      ...      ...     ...
# 251         251  20220615_25 (4).JPG  125       25     (4).   wheat
# 252         252  20220701_25 (1).JPG  141       25     (1).   wheat
# 253         253  20220701_25 (2).JPG  141       25     (2).   wheat
# 254         254  20220701_25 (3).JPG  141       25     (3).   wheat
# 255         255  20220701_25 (4).JPG  141       25     (4).   wheat
#
#     water_treatment management  plot m2  avg_water (L m-2)  ...  \
# 0                ww       conv       12          3096.2375  ...
# 1                ww       conv       12          3096.2375  ...
# 2                ww       conv       12          3096.2375  ...
# 3                ww       conv       12          3096.2375  ...
# 4                ww       conv       12          3096.2375  ...
# ..              ...        ...      ...                ...  ...
# 251               d       conv       12          2752.8000  ...
# 252               d       conv       12          2752.8000  ...
# 253               d       conv       12          2752.8000  ...
# 254               d       conv       12          2752.8000  ...
# 255               d       conv       12          2752.8000  ...
#
#      P (kg microplot-1)  K (kg microplot-1)  avg_height        GA       GGA  \
# 0                 0.072               0.072     46.9715  0.959407  0.904393
# 1                 0.072               0.072     46.9715  0.963030  0.905523
# 2                 0.072               0.072     46.9715  0.953708  0.898722
# 3                 0.072               0.072     46.9715  0.957117  0.898772
# 4                 0.072               0.072     46.9715  0.892348  0.791199
# ..                  ...                 ...         ...       ...       ...
# 251               0.072               0.072     55.2110  0.788544  0.323428
# 252               0.072               0.072     55.2110  0.031868  0.009072
# 253               0.072               0.072     55.2110  0.025828  0.006849
# 254               0.072               0.072     55.2110  0.022065  0.004773
# 255               0.072               0.072     55.2110  0.026765  0.007124
#
#            CSI  NGRDIveg     TGIveg  final yield (kg)  dataset
# 0     5.734098    0.1324  2569.2709              9.15    train
# 1     5.971505    0.1316  2648.0105              9.15    train
# 2     5.765430    0.1331  2736.4337              9.15    train
# 3     6.095965    0.1267  2550.8238              9.15    train
# 4    11.335180    0.1008  1880.2128              9.15    train
# ..         ...       ...        ...               ...      ...
# 251  58.984136    0.0491  2277.6824              7.95     test
# 252  71.532905    0.0342   946.1760              7.95     test
# 253  73.483356    0.0314   867.4491              7.95     test
# 254  78.367629    0.0196   855.3556              7.95     test
# 255  73.384338    0.0265   979.4368              7.95     test
#
# [256 rows x 21 columns]

# %%
scaler = MinMaxScaler()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'file', 'DAS', 'plot nº', 'photo nº', 'species',
#        'water_treatment', 'management', 'plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)', 'dataset'],
#       dtype='object')

# %%
dftrain = df[(df.dataset=='train')]
# dftrain.loc[:,['plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)']] = scaler.fit_transform(dftrain[['plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)']])
dfvalid = df[(df.dataset=='validation')]
dftest = df[(df.dataset=='test')]
# dfvalid.loc[:,['plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)']] = scaler.transform(dfvalid[['plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)']])        
# dftest.loc[:,['plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)']] = scaler.transform(dftest[['plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)']])

# %%
dftrain = pd.concat([dftrain,dfvalid])

# %%
df = pd.concat([dftrain,dftest])

# %%
dftrain.loc[:,'dataset'] =  dftrain['dataset'].apply(lambda x: x=='validation')
df.loc[:,'dataset'] =  df['dataset'].apply(lambda x: x=='test')

# %%
# dftrain.loc[:,'final yield (kg)'] = dftrain['final yield (kg)'].apply(lambda x : (x - 0.8579)/(10.55-0.8579))
# df.loc[:,'final yield (kg)'] = df['final yield (kg)'].apply(lambda x : (x - 0.8579)/(10.55-0.8579))

# %%
from fastai.vision.all import *
callbacks = [
    ShowGraphCallback(),
    # EarlyStoppingCallback(patience=5),
    SaveModelCallback(fname=name+'_No_WNPK_new'), #convnext_yield_all_minmax
    # ReduceLROnPlateau()
]

# %%
from fastai.metrics import mae,rmse,mse

# %%
db = DataBlock(blocks = (ImageBlock,
                         RegressionBlock(),RegressionBlock(),RegressionBlock(),
                         RegressionBlock(),RegressionBlock(),RegressionBlock()),
                 get_x=[ColReader('file',pref='wheat_all/'),
                    
                        ],
                 get_y=[#ColReader('species'),
                        #ColReader('water_treatment'),
                        #ColReader('management'),
                        #ColReader('plot m2'),
                        #ColReader('avg_height'),
                        #ColReader('avg_water (L m-2)'),
                        #ColReader('N (kg microplot-1)'),
                        #ColReader('P (kg microplot-1)'),
                        #ColReader('K (kg microplot-1)'),
                        
                        ColReader('GA'),
                        ColReader('GGA'),
                        ColReader('CSI'),
                        ColReader('NGRDIveg'),
                        ColReader('TGIveg'),
                     ColReader('final yield (kg)')],
                 splitter=ColSplitter(col='dataset'),    
                 item_tfms = Resize(512),
                 batch_tfms=[*aug_transforms(size=384,flip_vert=True,
                                            max_zoom=1.0), Normalize.from_stats(*imagenet_stats)],
               n_inp=1)
dls = db.dataloaders(dftrain,bs=4)

# %%
class MultiInputModel(Module):
  "A three-headed model given a `body` and `n` output features"
  def __init__(self, body:nn.Sequential):
    nf = 1
    self.body = body
    #self.water_treatment = create_head(nf, 4)
    #self.management = create_head(nf, 2)
    self.avg_water = create_head(nf,1)
    self.n = create_head(nf,1)
    self.p = create_head(nf,1)
    self.k = create_head(nf,1)
    self.avg_height = create_head(nf,1)
    self.ga = create_head(nf,1)
    self.gga = create_head(nf,1)
    self.csi = create_head(nf,1)
    self.NGRDIveg = create_head(nf,1)
    self.TGIveg = create_head(nf,1)
    self.yieldprod = create_head(nf,1)

    
    
  
  def forward(self, x):
    y = self.body(x)
    return [
        #self.water_treatment(y),
        #self.management(y),
        self.avg_water(y),
        self.n(y),
        self.p(y),
        self.k(y),
        self.avg_height(y),
        self.ga(y),
        self.gga(y),
        self.csi(y),
        self.NGRDIveg(y),
        self.TGIveg(y),
        self.yieldprod(y)]

# %%
model = timm.create_model(name,num_classes=1,pretrained=True)
body = nn.Sequential(*list(model.children())[:-1])
net = MultiInputModel(body)

# %%
class CombinationLoss(Module):
    "Cross Entropy Loss on multiple targets"
    def __init__(self, func1=F.cross_entropy,func2=F.mse_loss, weights=[2, 1]):
        self.func1, self.func2, self.w = func2, func2, weights

    def forward(self, xs, *ys, reduction='mean'):
        res = self.func2(ys[0],torch.reshape(xs[0],(4,1)))
        for i in range(1,5):
            res = res + self.func2(ys[i],torch.reshape(xs[i],(4,1)))
        res = res + self.func2(ys[5],torch.reshape(xs[5],(4,1)))
        return res

# %%
learn = Learner(dls, net, loss_func=CombinationLoss(),cbs=callbacks)

# %%
# learn.lr_find()

# %%
learn.freeze()

# %%
learn.fit_one_cycle(50,lr_max=1e-3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>8069149.000000</td>
#       <td>8155999.000000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>8143283.500000</td>
#       <td>8158797.500000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>8125728.500000</td>
#       <td>8155780.500000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>8092258.500000</td>
#       <td>8154358.500000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>8128855.000000</td>
#       <td>8149367.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>8172951.000000</td>
#       <td>8153732.500000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>8221634.000000</td>
#       <td>8159263.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>8098669.500000</td>
#       <td>8147757.500000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>8159852.000000</td>
#       <td>8145327.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>8188121.000000</td>
#       <td>8138553.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>8259307.000000</td>
#       <td>8168441.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>8146550.500000</td>
#       <td>8117052.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>8177661.500000</td>
#       <td>8139781.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>8117673.000000</td>
#       <td>8142997.500000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>8083902.500000</td>
#       <td>8054670.500000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>8108403.000000</td>
#       <td>8048566.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>7903080.500000</td>
#       <td>7895049.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>7972581.000000</td>
#       <td>7851237.500000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>7869546.500000</td>
#       <td>7796042.500000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>7827214.500000</td>
#       <td>7806435.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>7750317.500000</td>
#       <td>7818359.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>7517996.500000</td>
#       <td>7545879.000000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>7476378.500000</td>
#       <td>7548149.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>7375247.000000</td>
#       <td>7396543.500000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>7305514.500000</td>
#       <td>7512539.500000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>7278967.500000</td>
#       <td>7346586.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>7003943.500000</td>
#       <td>7303803.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>7109302.000000</td>
#       <td>7073256.500000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>7098978.000000</td>
#       <td>7054872.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>7038183.500000</td>
#       <td>6948528.000000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>6880903.000000</td>
#       <td>6902521.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>6776113.000000</td>
#       <td>6956560.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>6872970.000000</td>
#       <td>6705908.500000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>6709810.000000</td>
#       <td>6676233.500000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>6753329.000000</td>
#       <td>6630195.500000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>6704342.000000</td>
#       <td>6601072.500000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>6626178.500000</td>
#       <td>6564985.500000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>6678108.000000</td>
#       <td>6524262.500000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>6582987.000000</td>
#       <td>6488511.500000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>6483240.000000</td>
#       <td>6463242.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>6480323.000000</td>
#       <td>6465790.500000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>6518019.500000</td>
#       <td>6422441.500000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>6491551.000000</td>
#       <td>6397214.500000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>6523778.000000</td>
#       <td>6393929.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>6416943.000000</td>
#       <td>6394863.000000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>6483260.500000</td>
#       <td>6395060.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>6416403.500000</td>
#       <td>6387252.500000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>6455613.000000</td>
#       <td>6386994.000000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>6406199.500000</td>
#       <td>6386893.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>6404088.500000</td>
#       <td>6390778.000000</td>
#       <td>00:24</td>
#     </tr>
#   </tbody>
# </table>
# /tmp/ipykernel_2575056/2346873955.py:7: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = self.func2(ys[0],torch.reshape(xs[0],(4,1)))
# /tmp/ipykernel_2575056/2346873955.py:9: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = res + self.func2(ys[i],torch.reshape(xs[i],(4,1)))
# /tmp/ipykernel_2575056/2346873955.py:10: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = res + self.func2(ys[5],torch.reshape(xs[5],(4,1)))
# Better model found at epoch 0 with valid_loss value: 8155999.0.
# Better model found at epoch 2 with valid_loss value: 8155780.5.
# Better model found at epoch 3 with valid_loss value: 8154358.5.
# Better model found at epoch 4 with valid_loss value: 8149367.0.
# Better model found at epoch 7 with valid_loss value: 8147757.5.
# Better model found at epoch 8 with valid_loss value: 8145327.0.
# Better model found at epoch 9 with valid_loss value: 8138553.0.
# Better model found at epoch 11 with valid_loss value: 8117052.0.
# Better model found at epoch 14 with valid_loss value: 8054670.5.
# Better model found at epoch 15 with valid_loss value: 8048566.0.
# Better model found at epoch 16 with valid_loss value: 7895049.0.
# Better model found at epoch 17 with valid_loss value: 7851237.5.
# Better model found at epoch 18 with valid_loss value: 7796042.5.
# Better model found at epoch 21 with valid_loss value: 7545879.0.
# Better model found at epoch 23 with valid_loss value: 7396543.5.
# Better model found at epoch 25 with valid_loss value: 7346586.0.
# Better model found at epoch 26 with valid_loss value: 7303803.0.
# Better model found at epoch 27 with valid_loss value: 7073256.5.
# Better model found at epoch 28 with valid_loss value: 7054872.0.
# Better model found at epoch 29 with valid_loss value: 6948528.0.
# Better model found at epoch 30 with valid_loss value: 6902521.0.
# Better model found at epoch 32 with valid_loss value: 6705908.5.
# Better model found at epoch 33 with valid_loss value: 6676233.5.
# Better model found at epoch 34 with valid_loss value: 6630195.5.
# Better model found at epoch 35 with valid_loss value: 6601072.5.
# Better model found at epoch 36 with valid_loss value: 6564985.5.
# Better model found at epoch 37 with valid_loss value: 6524262.5.
# Better model found at epoch 38 with valid_loss value: 6488511.5.
# Better model found at epoch 39 with valid_loss value: 6463242.0.
# Better model found at epoch 41 with valid_loss value: 6422441.5.
# Better model found at epoch 42 with valid_loss value: 6397214.5.
# Better model found at epoch 43 with valid_loss value: 6393929.0.
# Better model found at epoch 46 with valid_loss value: 6387252.5.
# Better model found at epoch 47 with valid_loss value: 6386994.0.
# Better model found at epoch 48 with valid_loss value: 6386893.0.

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(50,lr_max=1e-4)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6387851.000000</td>
#       <td>6365475.000000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6464233.000000</td>
#       <td>6383907.500000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6424249.000000</td>
#       <td>6374430.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6337083.500000</td>
#       <td>6359127.500000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6381291.000000</td>
#       <td>6375382.500000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>6316523.000000</td>
#       <td>6381661.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>6295328.000000</td>
#       <td>6360299.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>6310046.000000</td>
#       <td>6361409.500000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>6357483.500000</td>
#       <td>6381938.500000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>6349659.500000</td>
#       <td>6341564.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>6452502.500000</td>
#       <td>6342195.000000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>6374277.500000</td>
#       <td>6328217.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>6385470.500000</td>
#       <td>6302471.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>6343318.000000</td>
#       <td>6320591.500000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>6236129.500000</td>
#       <td>6253540.500000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>6220709.000000</td>
#       <td>6229241.500000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>6269504.500000</td>
#       <td>6245334.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>6256387.000000</td>
#       <td>6219841.500000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>6220460.500000</td>
#       <td>6241222.500000</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>6163586.500000</td>
#       <td>6263360.500000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>6249407.500000</td>
#       <td>6214900.500000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>6190836.500000</td>
#       <td>6178537.000000</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>6261761.500000</td>
#       <td>6183494.000000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>6191989.500000</td>
#       <td>6161168.000000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>6142355.000000</td>
#       <td>6149636.000000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>6177837.500000</td>
#       <td>6147533.500000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>6188342.000000</td>
#       <td>6131808.000000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>6144372.500000</td>
#       <td>6121307.000000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>6190891.000000</td>
#       <td>6181000.500000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>6158463.500000</td>
#       <td>6113590.500000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>6188644.000000</td>
#       <td>6086722.000000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>6104570.000000</td>
#       <td>6100267.500000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>6128443.500000</td>
#       <td>6067598.500000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>6109053.500000</td>
#       <td>6076790.500000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>6213898.000000</td>
#       <td>6063712.500000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>6134338.000000</td>
#       <td>6058044.000000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>6106810.500000</td>
#       <td>6063088.500000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>6026418.000000</td>
#       <td>6068757.500000</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>6142103.000000</td>
#       <td>6066079.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>6124855.500000</td>
#       <td>6070498.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>6076488.000000</td>
#       <td>6066548.500000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>6045692.500000</td>
#       <td>6070264.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>6095604.500000</td>
#       <td>6068217.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>6111210.500000</td>
#       <td>6070910.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>6038721.500000</td>
#       <td>6061474.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>6012332.000000</td>
#       <td>6059141.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>5919539.000000</td>
#       <td>6060555.000000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>6048281.500000</td>
#       <td>6063497.500000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>5999222.500000</td>
#       <td>6053220.500000</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>6036551.000000</td>
#       <td>6045207.500000</td>
#       <td>00:23</td>
#     </tr>
#   </tbody>
# </table>
# /tmp/ipykernel_2575056/2346873955.py:7: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = self.func2(ys[0],torch.reshape(xs[0],(4,1)))
# /tmp/ipykernel_2575056/2346873955.py:9: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = res + self.func2(ys[i],torch.reshape(xs[i],(4,1)))
# /tmp/ipykernel_2575056/2346873955.py:10: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = res + self.func2(ys[5],torch.reshape(xs[5],(4,1)))
# Better model found at epoch 0 with valid_loss value: 6365475.0.
# Better model found at epoch 3 with valid_loss value: 6359127.5.
# Better model found at epoch 9 with valid_loss value: 6341564.0.
# Better model found at epoch 11 with valid_loss value: 6328217.0.
# Better model found at epoch 12 with valid_loss value: 6302471.0.
# Better model found at epoch 14 with valid_loss value: 6253540.5.
# Better model found at epoch 15 with valid_loss value: 6229241.5.
# Better model found at epoch 17 with valid_loss value: 6219841.5.
# Better model found at epoch 20 with valid_loss value: 6214900.5.
# Better model found at epoch 21 with valid_loss value: 6178537.0.
# Better model found at epoch 23 with valid_loss value: 6161168.0.
# Better model found at epoch 24 with valid_loss value: 6149636.0.
# Better model found at epoch 25 with valid_loss value: 6147533.5.
# Better model found at epoch 26 with valid_loss value: 6131808.0.
# Better model found at epoch 27 with valid_loss value: 6121307.0.
# Better model found at epoch 29 with valid_loss value: 6113590.5.
# Better model found at epoch 30 with valid_loss value: 6086722.0.
# Better model found at epoch 32 with valid_loss value: 6067598.5.
# Better model found at epoch 34 with valid_loss value: 6063712.5.
# Better model found at epoch 35 with valid_loss value: 6058044.0.
# Better model found at epoch 48 with valid_loss value: 6053220.5.
# Better model found at epoch 49 with valid_loss value: 6045207.5.

# %%
dls = db.dataloaders(df,bs=4)
learn.dls=dls

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
preds,gt = learn.get_preds()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# /tmp/ipykernel_2575056/2346873955.py:7: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = self.func2(ys[0],torch.reshape(xs[0],(4,1)))
# /tmp/ipykernel_2575056/2346873955.py:9: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = res + self.func2(ys[i],torch.reshape(xs[i],(4,1)))
# /tmp/ipykernel_2575056/2346873955.py:10: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = res + self.func2(ys[5],torch.reshape(xs[5],(4,1)))

# %%
print(gt[-1])
# Out:
# tensor([ 2.4077,  2.4077,  2.4077,  2.4077,  2.4077,  2.4077,  2.4077,  2.4077,
#          2.4077,  2.4077,  2.4077,  2.4077,  2.4077,  2.4077,  2.4077,  2.4077,
#         11.3500, 11.3500, 11.3500, 11.3500, 11.3500, 11.3500, 11.3500, 11.3500,
#         11.3500, 11.3500, 11.3500, 11.3500, 11.3500, 11.3500, 11.3500, 11.3500,
#          1.7521,  1.7521,  1.7521,  1.7521,  1.7521,  1.7521,  1.7521,  1.7521,
#          1.7521,  1.7521,  1.7521,  1.7521,  1.7521,  1.7521,  1.7521,  1.7521,
#          7.9500,  7.9500,  7.9500,  7.9500,  7.9500,  7.9500,  7.9500,  7.9500,
#          7.9500,  7.9500,  7.9500,  7.9500,  7.9500,  7.9500,  7.9500,  7.9500])

# %%
mean_absolute_error(gt[-1],preds[-1])
# Out:
# 5.381595

# %%
mean_squared_error(gt[-1],preds[-1])
# Out:
# 44.783722

# %%
math.sqrt(mean_squared_error(gt[-1],preds[-1]))
# Out:
# 6.692064100397435
