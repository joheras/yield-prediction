# %%
from fastai.vision.all import *
import fastai
import timm
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
# Out:
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")

# %%
import torch
torch.cuda.set_device(1)

# %%
df = pd.read_csv('data/wheat_new.csv',decimal=',')

# %%
name = 'swinv2_cr_base_384'

# %%
df
# Out:
#      Unnamed: 0                 file  DAS  plot nº photo nº species  \
# 0             0   20220517_1 (1).JPG   96        1     (1).   wheat
# 1             1   20220517_1 (2).JPG   96        1     (2).   wheat
# 2             2   20220517_1 (3).JPG   96        1     (3).   wheat
# 3             3   20220517_1 (4).JPG   96        1     (4).   wheat
# 4             4   20220602_1 (1).JPG  112        1     (1).   wheat
# ..          ...                  ...  ...      ...      ...     ...
# 251         251  20220615_25 (4).JPG  125       25     (4).   wheat
# 252         252  20220701_25 (1).JPG  141       25     (1).   wheat
# 253         253  20220701_25 (2).JPG  141       25     (2).   wheat
# 254         254  20220701_25 (3).JPG  141       25     (3).   wheat
# 255         255  20220701_25 (4).JPG  141       25     (4).   wheat
#
#     water_treatment management  plot m2  avg_water (L m-2)  ...  \
# 0                ww       conv       12          3096.2375  ...
# 1                ww       conv       12          3096.2375  ...
# 2                ww       conv       12          3096.2375  ...
# 3                ww       conv       12          3096.2375  ...
# 4                ww       conv       12          3096.2375  ...
# ..              ...        ...      ...                ...  ...
# 251               d       conv       12          2752.8000  ...
# 252               d       conv       12          2752.8000  ...
# 253               d       conv       12          2752.8000  ...
# 254               d       conv       12          2752.8000  ...
# 255               d       conv       12          2752.8000  ...
#
#      P (kg microplot-1)  K (kg microplot-1)  avg_height        GA       GGA  \
# 0                 0.072               0.072     46.9715  0.959407  0.904393
# 1                 0.072               0.072     46.9715  0.963030  0.905523
# 2                 0.072               0.072     46.9715  0.953708  0.898722
# 3                 0.072               0.072     46.9715  0.957117  0.898772
# 4                 0.072               0.072     46.9715  0.892348  0.791199
# ..                  ...                 ...         ...       ...       ...
# 251               0.072               0.072     55.2110  0.788544  0.323428
# 252               0.072               0.072     55.2110  0.031868  0.009072
# 253               0.072               0.072     55.2110  0.025828  0.006849
# 254               0.072               0.072     55.2110  0.022065  0.004773
# 255               0.072               0.072     55.2110  0.026765  0.007124
#
#            CSI  NGRDIveg     TGIveg  final yield (kg)  dataset
# 0     5.734098    0.1324  2569.2709              9.15    train
# 1     5.971505    0.1316  2648.0105              9.15    train
# 2     5.765430    0.1331  2736.4337              9.15    train
# 3     6.095965    0.1267  2550.8238              9.15    train
# 4    11.335180    0.1008  1880.2128              9.15    train
# ..         ...       ...        ...               ...      ...
# 251  58.984136    0.0491  2277.6824              7.95     test
# 252  71.532905    0.0342   946.1760              7.95     test
# 253  73.483356    0.0314   867.4491              7.95     test
# 254  78.367629    0.0196   855.3556              7.95     test
# 255  73.384338    0.0265   979.4368              7.95     test
#
# [256 rows x 21 columns]

# %%
scaler = MinMaxScaler()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'file', 'DAS', 'plot nº', 'photo nº', 'species',
#        'water_treatment', 'management', 'plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)', 'dataset'],
#       dtype='object')

# %%
dftrain = df[(df.dataset=='train')]
# dftrain.loc[:,['plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)']] = scaler.fit_transform(dftrain[['plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)']])
dfvalid = df[(df.dataset=='validation')]
dftest = df[(df.dataset=='test')]
# dfvalid.loc[:,['plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)']] = scaler.transform(dfvalid[['plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)']])        
# dftest.loc[:,['plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)']] = scaler.transform(dftest[['plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)']])

# %%
dftrain = pd.concat([dftrain,dfvalid])

# %%
df = pd.concat([dftrain,dftest])

# %%
dftrain.loc[:,'dataset'] =  dftrain['dataset'].apply(lambda x: x=='validation')
df.loc[:,'dataset'] =  df['dataset'].apply(lambda x: x=='test')

# %%
# dftrain.loc[:,'final yield (kg)'] = dftrain['final yield (kg)'].apply(lambda x : (x - 0.8579)/(10.55-0.8579))
# df.loc[:,'final yield (kg)'] = df['final yield (kg)'].apply(lambda x : (x - 0.8579)/(10.55-0.8579))

# %%
from fastai.vision.all import *
callbacks = [
    ShowGraphCallback(),
    # EarlyStoppingCallback(patience=5),
    SaveModelCallback(fname=name+'_WNPK_new'), #convnext_yield_all_minmax
    # ReduceLROnPlateau()
]

# %%
from fastai.metrics import mae,rmse,mse

# %%
db = DataBlock(blocks = (ImageBlock,
                         RegressionBlock(),RegressionBlock(),RegressionBlock(),RegressionBlock(),
                         RegressionBlock(),RegressionBlock(),RegressionBlock()),
                 get_x=[ColReader('file',pref='wheat_all/'),
                    
                        ],
                 get_y=[#ColReader('species'),
                        #ColReader('water_treatment'),
                        #ColReader('management'),
                        ColReader('plot m2'),
                        ColReader('avg_height'),
                        ColReader('avg_water (L m-2)'),
                        ColReader('N (kg microplot-1)'),
                        ColReader('P (kg microplot-1)'),
                        ColReader('K (kg microplot-1)'),
                        ColReader('final yield (kg)')],
                        # ColReader('GA'),
                        # ColReader('GGA'),
                        # ColReader('CSI'),
                        # ColReader('NGRDIveg'),
                        # ColReader('TGIveg')
                 splitter=ColSplitter(col='dataset'),    
                 item_tfms = Resize(512),
                 batch_tfms=[*aug_transforms(size=384,flip_vert=True,
                                            max_zoom=1.0), Normalize.from_stats(*imagenet_stats)],
               n_inp=1)
dls = db.dataloaders(dftrain,bs=4)

# %%
class MultiInputModel(Module):
  "A three-headed model given a `body` and `n` output features"
  def __init__(self, body:nn.Sequential):
    nf = 1024
    self.body = body
    #self.water_treatment = create_head(nf, 4)
    #self.management = create_head(nf, 2)
    self.avg_water = create_head(nf,1)
    self.n = create_head(nf,1)
    self.p = create_head(nf,1)
    self.k = create_head(nf,1)
    self.avg_height = create_head(nf,1)
    self.ga = create_head(nf,1)
    self.gga = create_head(nf,1)
    self.csi = create_head(nf,1)
    self.NGRDIveg = create_head(nf,1)
    self.TGIveg = create_head(nf,1)
    self.yieldprod = create_head(nf,1)

    
    
  
  def forward(self, x):
    y = self.body(x)
    return [
        #self.water_treatment(y),
        #self.management(y),
        self.avg_water(y),
        self.n(y),
        self.p(y),
        self.k(y),
        self.avg_height(y),
        self.ga(y),
        self.gga(y),
        self.csi(y),
        self.NGRDIveg(y),
        self.TGIveg(y),
        self.yieldprod(y)]

# %%
model = timm.create_model(name,num_classes=1,pretrained=True)
body = nn.Sequential(*list(model.children())[:-1])
net = MultiInputModel(body)
# Out:
# No pretrained weights exist or were found for this model. Using random initialization.

# %%
class CombinationLoss(Module):
    "Cross Entropy Loss on multiple targets"
    def __init__(self, func1=F.cross_entropy,func2=F.mse_loss, weights=[2, 1]):
        self.func1, self.func2, self.w = func2, func2, weights

    def forward(self, xs, *ys, reduction='mean'):
        res = self.func2(ys[0],torch.reshape(xs[0],(4,1)))
        for i in range(1,6):
            res = res + self.func2(ys[i],torch.reshape(xs[i],(4,1)))
        res = res + self.func2(ys[6],torch.reshape(xs[6],(4,1)))
        return res

# %%
learn = Learner(dls, net, loss_func=CombinationLoss(),cbs=callbacks)

# %%
# learn.lr_find()

# %%
learn.freeze()

# %%
learn.fit_one_cycle(50,lr_max=1e-3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>8130825.000000</td>
#       <td>9426135.000000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>8153982.000000</td>
#       <td>9425272.000000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>8135946.000000</td>
#       <td>9423957.000000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>8147124.000000</td>
#       <td>9425079.000000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>8163555.000000</td>
#       <td>9423213.000000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>8151169.000000</td>
#       <td>9422771.000000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>8145186.000000</td>
#       <td>9421077.000000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>8141277.000000</td>
#       <td>9416339.000000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>8150181.000000</td>
#       <td>9411842.000000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>8132870.000000</td>
#       <td>9403556.000000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>8127721.000000</td>
#       <td>9384441.000000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>8125429.000000</td>
#       <td>9362430.000000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>8100362.000000</td>
#       <td>9326984.000000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>8070936.000000</td>
#       <td>9296758.000000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>8038364.500000</td>
#       <td>9243061.000000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>7995601.000000</td>
#       <td>9199913.000000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>7940847.000000</td>
#       <td>9119171.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>7875400.000000</td>
#       <td>9051558.000000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>7796751.500000</td>
#       <td>8952543.000000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>7725716.000000</td>
#       <td>8846103.000000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>7652420.500000</td>
#       <td>8753252.000000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>7565773.500000</td>
#       <td>8658988.000000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>7465062.000000</td>
#       <td>8575740.000000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>7395260.500000</td>
#       <td>8488671.000000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>7299562.000000</td>
#       <td>8362094.500000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>7204820.500000</td>
#       <td>8317147.500000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>7114310.000000</td>
#       <td>8221962.500000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>7046670.000000</td>
#       <td>8098852.500000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>6929907.000000</td>
#       <td>8011256.000000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>6855797.500000</td>
#       <td>7931824.500000</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>6777590.000000</td>
#       <td>7855333.500000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>6693327.500000</td>
#       <td>7770634.500000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>6626939.500000</td>
#       <td>7696042.000000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>6560575.500000</td>
#       <td>7636808.000000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>6508137.000000</td>
#       <td>7576060.000000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>6444027.500000</td>
#       <td>7529767.500000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>6403941.500000</td>
#       <td>7462532.500000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>6365384.500000</td>
#       <td>7449069.500000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>6332944.500000</td>
#       <td>7397372.500000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>6290186.000000</td>
#       <td>7381145.500000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>6265953.500000</td>
#       <td>7340708.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>6253630.500000</td>
#       <td>7323503.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>6226504.500000</td>
#       <td>7305007.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>6210510.000000</td>
#       <td>7278448.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>6197340.000000</td>
#       <td>7277644.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>6200187.500000</td>
#       <td>7267078.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>6183586.500000</td>
#       <td>7274420.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>6166274.500000</td>
#       <td>7271164.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>6177078.500000</td>
#       <td>7265080.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>6180755.500000</td>
#       <td>7263367.000000</td>
#       <td>00:16</td>
#     </tr>
#   </tbody>
# </table>
# /tmp/ipykernel_906954/3279080324.py:7: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = self.func2(ys[0],torch.reshape(xs[0],(4,1)))
# /tmp/ipykernel_906954/3279080324.py:9: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = res + self.func2(ys[i],torch.reshape(xs[i],(4,1)))
# /tmp/ipykernel_906954/3279080324.py:10: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = res + self.func2(ys[6],torch.reshape(xs[6],(4,1)))
# Better model found at epoch 0 with valid_loss value: 9426135.0.
# Better model found at epoch 1 with valid_loss value: 9425272.0.
# Better model found at epoch 2 with valid_loss value: 9423957.0.
# Better model found at epoch 4 with valid_loss value: 9423213.0.
# Better model found at epoch 5 with valid_loss value: 9422771.0.
# Better model found at epoch 6 with valid_loss value: 9421077.0.
# Better model found at epoch 7 with valid_loss value: 9416339.0.
# Better model found at epoch 8 with valid_loss value: 9411842.0.
# Better model found at epoch 9 with valid_loss value: 9403556.0.
# Better model found at epoch 10 with valid_loss value: 9384441.0.
# Better model found at epoch 11 with valid_loss value: 9362430.0.
# Better model found at epoch 12 with valid_loss value: 9326984.0.
# Better model found at epoch 13 with valid_loss value: 9296758.0.
# Better model found at epoch 14 with valid_loss value: 9243061.0.
# Better model found at epoch 15 with valid_loss value: 9199913.0.
# Better model found at epoch 16 with valid_loss value: 9119171.0.
# Better model found at epoch 17 with valid_loss value: 9051558.0.
# Better model found at epoch 18 with valid_loss value: 8952543.0.
# Better model found at epoch 19 with valid_loss value: 8846103.0.
# Better model found at epoch 20 with valid_loss value: 8753252.0.
# Better model found at epoch 21 with valid_loss value: 8658988.0.
# Better model found at epoch 22 with valid_loss value: 8575740.0.
# Better model found at epoch 23 with valid_loss value: 8488671.0.
# Better model found at epoch 24 with valid_loss value: 8362094.5.
# Better model found at epoch 25 with valid_loss value: 8317147.5.
# Better model found at epoch 26 with valid_loss value: 8221962.5.
# Better model found at epoch 27 with valid_loss value: 8098852.5.
# Better model found at epoch 28 with valid_loss value: 8011256.0.
# Better model found at epoch 29 with valid_loss value: 7931824.5.
# Better model found at epoch 30 with valid_loss value: 7855333.5.
# Better model found at epoch 31 with valid_loss value: 7770634.5.
# Better model found at epoch 32 with valid_loss value: 7696042.0.
# Better model found at epoch 33 with valid_loss value: 7636808.0.
# Better model found at epoch 34 with valid_loss value: 7576060.0.
# Better model found at epoch 35 with valid_loss value: 7529767.5.
# Better model found at epoch 36 with valid_loss value: 7462532.5.
# Better model found at epoch 37 with valid_loss value: 7449069.5.
# Better model found at epoch 38 with valid_loss value: 7397372.5.
# Better model found at epoch 39 with valid_loss value: 7381145.5.
# Better model found at epoch 40 with valid_loss value: 7340708.5.
# Better model found at epoch 41 with valid_loss value: 7323503.0.
# Better model found at epoch 42 with valid_loss value: 7305007.5.
# Better model found at epoch 43 with valid_loss value: 7278448.0.
# Better model found at epoch 44 with valid_loss value: 7277644.0.
# Better model found at epoch 45 with valid_loss value: 7267078.0.
# Better model found at epoch 48 with valid_loss value: 7265080.5.
# Better model found at epoch 49 with valid_loss value: 7263367.0.

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(50,lr_max=1e-4)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6129068.500000</td>
#       <td>7258741.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6173606.000000</td>
#       <td>7266863.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6169217.500000</td>
#       <td>7251630.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6169205.500000</td>
#       <td>7272152.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6178678.000000</td>
#       <td>7245296.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>6176451.500000</td>
#       <td>7234253.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>6164618.500000</td>
#       <td>7238584.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>6155715.000000</td>
#       <td>7233544.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>6129776.500000</td>
#       <td>7211645.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>6123105.500000</td>
#       <td>7197347.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>6114620.500000</td>
#       <td>7183143.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>6093092.000000</td>
#       <td>7160253.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>6070654.000000</td>
#       <td>7148991.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>6055514.000000</td>
#       <td>7142500.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>6039723.500000</td>
#       <td>7121134.000000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>6030987.500000</td>
#       <td>7092101.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>5996838.000000</td>
#       <td>7090492.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>6006456.000000</td>
#       <td>7064634.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>5978715.500000</td>
#       <td>7051760.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>5953788.000000</td>
#       <td>7039268.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>5945510.000000</td>
#       <td>7024723.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>5914424.000000</td>
#       <td>7010451.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>5907005.500000</td>
#       <td>6990476.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>5909830.000000</td>
#       <td>6978240.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>5895393.500000</td>
#       <td>6970654.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>5891010.000000</td>
#       <td>6954419.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>5869515.500000</td>
#       <td>6936767.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>5867333.000000</td>
#       <td>6928682.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>5844779.000000</td>
#       <td>6905015.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>5848644.000000</td>
#       <td>6941473.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>5840907.000000</td>
#       <td>6886895.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>5822374.500000</td>
#       <td>6890794.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>5826424.000000</td>
#       <td>6889630.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>5835121.500000</td>
#       <td>6883091.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>5809504.500000</td>
#       <td>6867841.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>5811231.500000</td>
#       <td>6866623.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>5792678.500000</td>
#       <td>6851158.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>5823568.000000</td>
#       <td>6858353.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>5792937.000000</td>
#       <td>6853433.500000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>5785898.500000</td>
#       <td>6835381.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>5788834.500000</td>
#       <td>6859676.500000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>5783180.500000</td>
#       <td>6842688.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>5772613.000000</td>
#       <td>6825216.000000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>5778509.500000</td>
#       <td>6838892.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>5776929.500000</td>
#       <td>6849782.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>5782885.500000</td>
#       <td>6844214.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>5783657.000000</td>
#       <td>6847396.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>5787379.500000</td>
#       <td>6844224.500000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>5776480.000000</td>
#       <td>6845699.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>5770537.500000</td>
#       <td>6825650.500000</td>
#       <td>00:16</td>
#     </tr>
#   </tbody>
# </table>
# /tmp/ipykernel_906954/3279080324.py:7: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = self.func2(ys[0],torch.reshape(xs[0],(4,1)))
# /tmp/ipykernel_906954/3279080324.py:9: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = res + self.func2(ys[i],torch.reshape(xs[i],(4,1)))
# /tmp/ipykernel_906954/3279080324.py:10: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = res + self.func2(ys[6],torch.reshape(xs[6],(4,1)))
# Better model found at epoch 0 with valid_loss value: 7258741.0.
# Better model found at epoch 2 with valid_loss value: 7251630.0.
# Better model found at epoch 4 with valid_loss value: 7245296.5.
# Better model found at epoch 5 with valid_loss value: 7234253.0.
# Better model found at epoch 7 with valid_loss value: 7233544.0.
# Better model found at epoch 8 with valid_loss value: 7211645.0.
# Better model found at epoch 9 with valid_loss value: 7197347.0.
# Better model found at epoch 10 with valid_loss value: 7183143.5.
# Better model found at epoch 11 with valid_loss value: 7160253.5.
# Better model found at epoch 12 with valid_loss value: 7148991.0.
# Better model found at epoch 13 with valid_loss value: 7142500.5.
# Better model found at epoch 14 with valid_loss value: 7121134.0.
# Better model found at epoch 15 with valid_loss value: 7092101.0.
# Better model found at epoch 16 with valid_loss value: 7090492.0.
# Better model found at epoch 17 with valid_loss value: 7064634.0.
# Better model found at epoch 18 with valid_loss value: 7051760.0.
# Better model found at epoch 19 with valid_loss value: 7039268.5.
# Better model found at epoch 20 with valid_loss value: 7024723.5.
# Better model found at epoch 21 with valid_loss value: 7010451.5.
# Better model found at epoch 22 with valid_loss value: 6990476.0.
# Better model found at epoch 23 with valid_loss value: 6978240.5.
# Better model found at epoch 24 with valid_loss value: 6970654.0.
# Better model found at epoch 25 with valid_loss value: 6954419.0.
# Better model found at epoch 26 with valid_loss value: 6936767.5.
# Better model found at epoch 27 with valid_loss value: 6928682.5.
# Better model found at epoch 28 with valid_loss value: 6905015.0.
# Better model found at epoch 30 with valid_loss value: 6886895.0.
# Better model found at epoch 33 with valid_loss value: 6883091.5.
# Better model found at epoch 34 with valid_loss value: 6867841.5.
# Better model found at epoch 35 with valid_loss value: 6866623.0.
# Better model found at epoch 36 with valid_loss value: 6851158.0.
# Better model found at epoch 39 with valid_loss value: 6835381.0.
# Better model found at epoch 42 with valid_loss value: 6825216.0.

# %%
dls = db.dataloaders(df,bs=4)
learn.dls=dls

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
preds,gt = learn.get_preds()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# /tmp/ipykernel_906954/3279080324.py:7: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = self.func2(ys[0],torch.reshape(xs[0],(4,1)))
# /tmp/ipykernel_906954/3279080324.py:9: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = res + self.func2(ys[i],torch.reshape(xs[i],(4,1)))
# /tmp/ipykernel_906954/3279080324.py:10: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = res + self.func2(ys[6],torch.reshape(xs[6],(4,1)))

# %%
print(gt[-1])
# Out:
# tensor([ 2.4077,  2.4077,  2.4077,  2.4077,  2.4077,  2.4077,  2.4077,  2.4077,
#          2.4077,  2.4077,  2.4077,  2.4077,  2.4077,  2.4077,  2.4077,  2.4077,
#         11.3500, 11.3500, 11.3500, 11.3500, 11.3500, 11.3500, 11.3500, 11.3500,
#         11.3500, 11.3500, 11.3500, 11.3500, 11.3500, 11.3500, 11.3500, 11.3500,
#          1.7521,  1.7521,  1.7521,  1.7521,  1.7521,  1.7521,  1.7521,  1.7521,
#          1.7521,  1.7521,  1.7521,  1.7521,  1.7521,  1.7521,  1.7521,  1.7521,
#          7.9500,  7.9500,  7.9500,  7.9500,  7.9500,  7.9500,  7.9500,  7.9500,
#          7.9500,  7.9500,  7.9500,  7.9500,  7.9500,  7.9500,  7.9500,  7.9500])

# %%
mean_absolute_error(gt[-1],preds[-1])
# Out:
# 5.8211536

# %%
mean_squared_error(gt[-1],preds[-1])
# Out:
# 51.74839

# %%
math.sqrt(mean_squared_error(gt[-1],preds[-1]))
# Out:
# 7.1936353951082275
