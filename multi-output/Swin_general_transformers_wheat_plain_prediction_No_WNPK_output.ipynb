# %%
from fastai.vision.all import *
import fastai
import timm
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
# Out:
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")

# %%
import torch
torch.cuda.set_device(1)

# %%
df = pd.read_csv('data/wheat_new.csv',decimal=',')

# %%
name = 'swinv2_cr_base_384'

# %%
df
# Out:
#      Unnamed: 0                 file  DAS  plot nº photo nº species  \
# 0             0   20220517_1 (1).JPG   96        1     (1).   wheat
# 1             1   20220517_1 (2).JPG   96        1     (2).   wheat
# 2             2   20220517_1 (3).JPG   96        1     (3).   wheat
# 3             3   20220517_1 (4).JPG   96        1     (4).   wheat
# 4             4   20220602_1 (1).JPG  112        1     (1).   wheat
# ..          ...                  ...  ...      ...      ...     ...
# 251         251  20220615_25 (4).JPG  125       25     (4).   wheat
# 252         252  20220701_25 (1).JPG  141       25     (1).   wheat
# 253         253  20220701_25 (2).JPG  141       25     (2).   wheat
# 254         254  20220701_25 (3).JPG  141       25     (3).   wheat
# 255         255  20220701_25 (4).JPG  141       25     (4).   wheat
#
#     water_treatment management  plot m2  avg_water (L m-2)  ...  \
# 0                ww       conv       12          3096.2375  ...
# 1                ww       conv       12          3096.2375  ...
# 2                ww       conv       12          3096.2375  ...
# 3                ww       conv       12          3096.2375  ...
# 4                ww       conv       12          3096.2375  ...
# ..              ...        ...      ...                ...  ...
# 251               d       conv       12          2752.8000  ...
# 252               d       conv       12          2752.8000  ...
# 253               d       conv       12          2752.8000  ...
# 254               d       conv       12          2752.8000  ...
# 255               d       conv       12          2752.8000  ...
#
#      P (kg microplot-1)  K (kg microplot-1)  avg_height        GA       GGA  \
# 0                 0.072               0.072     46.9715  0.959407  0.904393
# 1                 0.072               0.072     46.9715  0.963030  0.905523
# 2                 0.072               0.072     46.9715  0.953708  0.898722
# 3                 0.072               0.072     46.9715  0.957117  0.898772
# 4                 0.072               0.072     46.9715  0.892348  0.791199
# ..                  ...                 ...         ...       ...       ...
# 251               0.072               0.072     55.2110  0.788544  0.323428
# 252               0.072               0.072     55.2110  0.031868  0.009072
# 253               0.072               0.072     55.2110  0.025828  0.006849
# 254               0.072               0.072     55.2110  0.022065  0.004773
# 255               0.072               0.072     55.2110  0.026765  0.007124
#
#            CSI  NGRDIveg     TGIveg  final yield (kg)  dataset
# 0     5.734098    0.1324  2569.2709              9.15    train
# 1     5.971505    0.1316  2648.0105              9.15    train
# 2     5.765430    0.1331  2736.4337              9.15    train
# 3     6.095965    0.1267  2550.8238              9.15    train
# 4    11.335180    0.1008  1880.2128              9.15    train
# ..         ...       ...        ...               ...      ...
# 251  58.984136    0.0491  2277.6824              7.95     test
# 252  71.532905    0.0342   946.1760              7.95     test
# 253  73.483356    0.0314   867.4491              7.95     test
# 254  78.367629    0.0196   855.3556              7.95     test
# 255  73.384338    0.0265   979.4368              7.95     test
#
# [256 rows x 21 columns]

# %%
scaler = MinMaxScaler()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'file', 'DAS', 'plot nº', 'photo nº', 'species',
#        'water_treatment', 'management', 'plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)', 'dataset'],
#       dtype='object')

# %%
dftrain = df[(df.dataset=='train')]
# dftrain.loc[:,['plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)']] = scaler.fit_transform(dftrain[['plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)']])
dfvalid = df[(df.dataset=='validation')]
dftest = df[(df.dataset=='test')]
# dfvalid.loc[:,['plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)']] = scaler.transform(dfvalid[['plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)']])        
# dftest.loc[:,['plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)']] = scaler.transform(dftest[['plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)']])

# %%
dftrain = pd.concat([dftrain,dfvalid])

# %%
df = pd.concat([dftrain,dftest])

# %%
dftrain.loc[:,'dataset'] =  dftrain['dataset'].apply(lambda x: x=='validation')
df.loc[:,'dataset'] =  df['dataset'].apply(lambda x: x=='test')

# %%
# dftrain.loc[:,'final yield (kg)'] = dftrain['final yield (kg)'].apply(lambda x : (x - 0.8579)/(10.55-0.8579))
# df.loc[:,'final yield (kg)'] = df['final yield (kg)'].apply(lambda x : (x - 0.8579)/(10.55-0.8579))

# %%
from fastai.vision.all import *
callbacks = [
    ShowGraphCallback(),
    # EarlyStoppingCallback(patience=5),
    SaveModelCallback(fname=name+'_No_WNPK_new'), #convnext_yield_all_minmax
    # ReduceLROnPlateau()
]

# %%
from fastai.metrics import mae,rmse,mse

# %%
db = DataBlock(blocks = (ImageBlock,
                         RegressionBlock(),RegressionBlock(),RegressionBlock(),
                         RegressionBlock(),RegressionBlock(),RegressionBlock()),
                 get_x=[ColReader('file',pref='wheat_all/'),
                    
                        ],
                 get_y=[#ColReader('species'),
                        #ColReader('water_treatment'),
                        #ColReader('management'),
                        #ColReader('plot m2'),
                        #ColReader('avg_height'),
                        #ColReader('avg_water (L m-2)'),
                        #ColReader('N (kg microplot-1)'),
                        #ColReader('P (kg microplot-1)'),
                        #ColReader('K (kg microplot-1)'),
                        
                        ColReader('GA'),
                        ColReader('GGA'),
                        ColReader('CSI'),
                        ColReader('NGRDIveg'),
                        ColReader('TGIveg'),
                     ColReader('final yield (kg)')],
                 splitter=ColSplitter(col='dataset'),    
                 item_tfms = Resize(512),
                 batch_tfms=[*aug_transforms(size=384,flip_vert=True,
                                            max_zoom=1.0), Normalize.from_stats(*imagenet_stats)],
               n_inp=1)
dls = db.dataloaders(dftrain,bs=4)

# %%
class MultiInputModel(Module):
  "A three-headed model given a `body` and `n` output features"
  def __init__(self, body:nn.Sequential):
    nf = 1024
    self.body = body
    #self.water_treatment = create_head(nf, 4)
    #self.management = create_head(nf, 2)
    self.avg_water = create_head(nf,1)
    self.n = create_head(nf,1)
    self.p = create_head(nf,1)
    self.k = create_head(nf,1)
    self.avg_height = create_head(nf,1)
    self.ga = create_head(nf,1)
    self.gga = create_head(nf,1)
    self.csi = create_head(nf,1)
    self.NGRDIveg = create_head(nf,1)
    self.TGIveg = create_head(nf,1)
    self.yieldprod = create_head(nf,1)

    
    
  
  def forward(self, x):
    y = self.body(x)
    return [
        #self.water_treatment(y),
        #self.management(y),
        self.avg_water(y),
        self.n(y),
        self.p(y),
        self.k(y),
        self.avg_height(y),
        self.ga(y),
        self.gga(y),
        self.csi(y),
        self.NGRDIveg(y),
        self.TGIveg(y),
        self.yieldprod(y)]

# %%
model = timm.create_model(name,num_classes=1,pretrained=True)
body = nn.Sequential(*list(model.children())[:-1])
net = MultiInputModel(body)
# Out:
# /home/joheras/.local/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# No pretrained weights exist or were found for this model. Using random initialization.

# %%
class CombinationLoss(Module):
    "Cross Entropy Loss on multiple targets"
    def __init__(self, func1=F.cross_entropy,func2=F.mse_loss, weights=[2, 1]):
        self.func1, self.func2, self.w = func2, func2, weights

    def forward(self, xs, *ys, reduction='mean'):
        res = self.func2(ys[0],torch.reshape(xs[0],(4,1)))
        for i in range(1,5):
            res = res + self.func2(ys[i],torch.reshape(xs[i],(4,1)))
        res = res + self.func2(ys[5],torch.reshape(xs[5],(4,1)))
        return res

# %%
learn = Learner(dls, net, loss_func=CombinationLoss(),cbs=callbacks)

# %%
# learn.lr_find()

# %%
learn.freeze()

# %%
learn.fit_one_cycle(50,lr_max=1e-3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>8317992.000000</td>
#       <td>8158093.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>8070315.500000</td>
#       <td>8157247.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>8133196.000000</td>
#       <td>8157171.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>8147283.000000</td>
#       <td>8157809.000000</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>8190016.000000</td>
#       <td>8156064.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>8237627.000000</td>
#       <td>8155118.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>8266515.000000</td>
#       <td>8153953.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>8278939.000000</td>
#       <td>8148402.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>8154880.500000</td>
#       <td>8144760.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>8195165.500000</td>
#       <td>8137714.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>8203583.500000</td>
#       <td>8127249.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>8103307.000000</td>
#       <td>8111291.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>7999867.000000</td>
#       <td>8073002.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>7921561.500000</td>
#       <td>8049145.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>8078796.500000</td>
#       <td>8002504.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>8187588.000000</td>
#       <td>7963393.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>8083050.000000</td>
#       <td>7890198.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>7909102.000000</td>
#       <td>7833185.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>7827721.500000</td>
#       <td>7785456.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>7900259.500000</td>
#       <td>7717738.500000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>7680127.500000</td>
#       <td>7633157.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>7545393.500000</td>
#       <td>7548482.500000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>7534412.500000</td>
#       <td>7463374.500000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>7504066.000000</td>
#       <td>7377642.000000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>7367822.500000</td>
#       <td>7306150.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>7234769.500000</td>
#       <td>7243233.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>7311648.500000</td>
#       <td>7146518.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>7157236.000000</td>
#       <td>7089034.500000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>7187282.500000</td>
#       <td>6998076.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>7132693.000000</td>
#       <td>6924031.500000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>6904629.000000</td>
#       <td>6859203.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>6952702.500000</td>
#       <td>6819058.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>6807354.500000</td>
#       <td>6761741.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>6705378.000000</td>
#       <td>6716344.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>6689661.000000</td>
#       <td>6654623.500000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>6617966.500000</td>
#       <td>6611776.500000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>6650192.000000</td>
#       <td>6578210.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>6609593.500000</td>
#       <td>6538247.000000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>6556346.500000</td>
#       <td>6515121.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>6502365.000000</td>
#       <td>6484634.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>6505449.000000</td>
#       <td>6472933.000000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>6465923.000000</td>
#       <td>6457354.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>6484990.500000</td>
#       <td>6440882.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>6430814.500000</td>
#       <td>6434367.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>6340938.000000</td>
#       <td>6429930.500000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>6409733.000000</td>
#       <td>6425998.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>6368406.000000</td>
#       <td>6420313.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>6485403.500000</td>
#       <td>6421069.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>6400703.500000</td>
#       <td>6422307.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>6370377.000000</td>
#       <td>6417761.000000</td>
#       <td>00:16</td>
#     </tr>
#   </tbody>
# </table>
# /tmp/ipykernel_2095463/2346873955.py:7: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = self.func2(ys[0],torch.reshape(xs[0],(4,1)))
# /tmp/ipykernel_2095463/2346873955.py:9: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = res + self.func2(ys[i],torch.reshape(xs[i],(4,1)))
# /tmp/ipykernel_2095463/2346873955.py:10: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = res + self.func2(ys[5],torch.reshape(xs[5],(4,1)))
# Better model found at epoch 0 with valid_loss value: 8158093.5.
# Better model found at epoch 1 with valid_loss value: 8157247.0.
# Better model found at epoch 2 with valid_loss value: 8157171.5.
# Better model found at epoch 4 with valid_loss value: 8156064.5.
# Better model found at epoch 5 with valid_loss value: 8155118.5.
# Better model found at epoch 6 with valid_loss value: 8153953.5.
# Better model found at epoch 7 with valid_loss value: 8148402.0.
# Better model found at epoch 8 with valid_loss value: 8144760.5.
# Better model found at epoch 9 with valid_loss value: 8137714.5.
# Better model found at epoch 10 with valid_loss value: 8127249.5.
# Better model found at epoch 11 with valid_loss value: 8111291.5.
# Better model found at epoch 12 with valid_loss value: 8073002.0.
# Better model found at epoch 13 with valid_loss value: 8049145.0.
# Better model found at epoch 14 with valid_loss value: 8002504.5.
# Better model found at epoch 15 with valid_loss value: 7963393.5.
# Better model found at epoch 16 with valid_loss value: 7890198.0.
# Better model found at epoch 17 with valid_loss value: 7833185.5.
# Better model found at epoch 18 with valid_loss value: 7785456.5.
# Better model found at epoch 19 with valid_loss value: 7717738.5.
# Better model found at epoch 20 with valid_loss value: 7633157.5.
# Better model found at epoch 21 with valid_loss value: 7548482.5.
# Better model found at epoch 22 with valid_loss value: 7463374.5.
# Better model found at epoch 23 with valid_loss value: 7377642.0.
# Better model found at epoch 24 with valid_loss value: 7306150.0.
# Better model found at epoch 25 with valid_loss value: 7243233.0.
# Better model found at epoch 26 with valid_loss value: 7146518.0.
# Better model found at epoch 27 with valid_loss value: 7089034.5.
# Better model found at epoch 28 with valid_loss value: 6998076.5.
# Better model found at epoch 29 with valid_loss value: 6924031.5.
# Better model found at epoch 30 with valid_loss value: 6859203.5.
# Better model found at epoch 31 with valid_loss value: 6819058.5.
# Better model found at epoch 32 with valid_loss value: 6761741.0.
# Better model found at epoch 33 with valid_loss value: 6716344.0.
# Better model found at epoch 34 with valid_loss value: 6654623.5.
# Better model found at epoch 35 with valid_loss value: 6611776.5.
# Better model found at epoch 36 with valid_loss value: 6578210.0.
# Better model found at epoch 37 with valid_loss value: 6538247.0.
# Better model found at epoch 38 with valid_loss value: 6515121.5.
# Better model found at epoch 39 with valid_loss value: 6484634.0.
# Better model found at epoch 40 with valid_loss value: 6472933.0.
# Better model found at epoch 41 with valid_loss value: 6457354.5.
# Better model found at epoch 42 with valid_loss value: 6440882.0.
# Better model found at epoch 43 with valid_loss value: 6434367.5.
# Better model found at epoch 44 with valid_loss value: 6429930.5.
# Better model found at epoch 45 with valid_loss value: 6425998.0.
# Better model found at epoch 46 with valid_loss value: 6420313.5.
# Better model found at epoch 49 with valid_loss value: 6417761.0.

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(50,lr_max=1e-4)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6389515.500000</td>
#       <td>6421345.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>6443044.000000</td>
#       <td>6421000.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6382897.500000</td>
#       <td>6408898.000000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6419179.000000</td>
#       <td>6411711.000000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>6368372.000000</td>
#       <td>6407153.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>6246947.000000</td>
#       <td>6403651.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>6366990.000000</td>
#       <td>6393221.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>6272481.500000</td>
#       <td>6386196.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>6410396.500000</td>
#       <td>6377378.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>6423867.000000</td>
#       <td>6363832.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>6375332.500000</td>
#       <td>6347871.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>6263690.500000</td>
#       <td>6339167.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>6367796.500000</td>
#       <td>6322419.500000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>6362385.000000</td>
#       <td>6308245.500000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>6338769.500000</td>
#       <td>6292247.500000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>6238692.500000</td>
#       <td>6281982.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>6245845.500000</td>
#       <td>6263437.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>6269954.000000</td>
#       <td>6250315.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>6220525.000000</td>
#       <td>6243579.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>6172013.500000</td>
#       <td>6230819.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>6073861.500000</td>
#       <td>6210957.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>6106990.000000</td>
#       <td>6210627.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>6162427.500000</td>
#       <td>6189800.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>6267761.000000</td>
#       <td>6181150.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>6215921.500000</td>
#       <td>6174208.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>6212445.500000</td>
#       <td>6163100.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>6205414.500000</td>
#       <td>6152805.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>6181235.500000</td>
#       <td>6146046.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>6115543.500000</td>
#       <td>6137630.500000</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>6113907.500000</td>
#       <td>6128648.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>6160134.500000</td>
#       <td>6124597.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>6080017.000000</td>
#       <td>6112728.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>6104439.000000</td>
#       <td>6107232.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>6129537.500000</td>
#       <td>6101849.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>6045547.500000</td>
#       <td>6090125.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>6086961.000000</td>
#       <td>6090508.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>6092994.500000</td>
#       <td>6087846.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>6021401.500000</td>
#       <td>6083437.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>6056906.500000</td>
#       <td>6078101.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>6083351.000000</td>
#       <td>6074748.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>6000777.000000</td>
#       <td>6073561.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>6101538.000000</td>
#       <td>6071725.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>6011134.000000</td>
#       <td>6070791.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>6130881.500000</td>
#       <td>6072529.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>6132404.000000</td>
#       <td>6068980.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>6160965.500000</td>
#       <td>6067572.500000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>6126410.500000</td>
#       <td>6069756.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>6099912.500000</td>
#       <td>6071971.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>6043616.500000</td>
#       <td>6071525.000000</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>5974885.500000</td>
#       <td>6069626.500000</td>
#       <td>00:16</td>
#     </tr>
#   </tbody>
# </table>
# /tmp/ipykernel_2095463/2346873955.py:7: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = self.func2(ys[0],torch.reshape(xs[0],(4,1)))
# /tmp/ipykernel_2095463/2346873955.py:9: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = res + self.func2(ys[i],torch.reshape(xs[i],(4,1)))
# /tmp/ipykernel_2095463/2346873955.py:10: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = res + self.func2(ys[5],torch.reshape(xs[5],(4,1)))
# Better model found at epoch 0 with valid_loss value: 6421345.0.
# Better model found at epoch 1 with valid_loss value: 6421000.0.
# Better model found at epoch 2 with valid_loss value: 6408898.0.
# Better model found at epoch 4 with valid_loss value: 6407153.5.
# Better model found at epoch 5 with valid_loss value: 6403651.5.
# Better model found at epoch 6 with valid_loss value: 6393221.0.
# Better model found at epoch 7 with valid_loss value: 6386196.0.
# Better model found at epoch 8 with valid_loss value: 6377378.5.
# Better model found at epoch 9 with valid_loss value: 6363832.0.
# Better model found at epoch 10 with valid_loss value: 6347871.0.
# Better model found at epoch 11 with valid_loss value: 6339167.5.
# Better model found at epoch 12 with valid_loss value: 6322419.5.
# Better model found at epoch 13 with valid_loss value: 6308245.5.
# Better model found at epoch 14 with valid_loss value: 6292247.5.
# Better model found at epoch 15 with valid_loss value: 6281982.5.
# Better model found at epoch 16 with valid_loss value: 6263437.0.
# Better model found at epoch 17 with valid_loss value: 6250315.5.
# Better model found at epoch 18 with valid_loss value: 6243579.5.
# Better model found at epoch 19 with valid_loss value: 6230819.5.
# Better model found at epoch 20 with valid_loss value: 6210957.5.
# Better model found at epoch 21 with valid_loss value: 6210627.5.
# Better model found at epoch 22 with valid_loss value: 6189800.0.
# Better model found at epoch 23 with valid_loss value: 6181150.0.
# Better model found at epoch 24 with valid_loss value: 6174208.0.
# Better model found at epoch 25 with valid_loss value: 6163100.0.
# Better model found at epoch 26 with valid_loss value: 6152805.5.
# Better model found at epoch 27 with valid_loss value: 6146046.0.
# Better model found at epoch 28 with valid_loss value: 6137630.5.
# Better model found at epoch 29 with valid_loss value: 6128648.5.
# Better model found at epoch 30 with valid_loss value: 6124597.0.
# Better model found at epoch 31 with valid_loss value: 6112728.5.
# Better model found at epoch 32 with valid_loss value: 6107232.5.
# Better model found at epoch 33 with valid_loss value: 6101849.0.
# Better model found at epoch 34 with valid_loss value: 6090125.5.
# Better model found at epoch 36 with valid_loss value: 6087846.0.
# Better model found at epoch 37 with valid_loss value: 6083437.0.
# Better model found at epoch 38 with valid_loss value: 6078101.0.
# Better model found at epoch 39 with valid_loss value: 6074748.5.
# Better model found at epoch 40 with valid_loss value: 6073561.5.
# Better model found at epoch 41 with valid_loss value: 6071725.5.
# Better model found at epoch 42 with valid_loss value: 6070791.5.
# Better model found at epoch 44 with valid_loss value: 6068980.5.
# Better model found at epoch 45 with valid_loss value: 6067572.5.

# %%
dls = db.dataloaders(df,bs=4)
learn.dls=dls

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
preds,gt = learn.get_preds()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# /tmp/ipykernel_2095463/2346873955.py:7: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = self.func2(ys[0],torch.reshape(xs[0],(4,1)))
# /tmp/ipykernel_2095463/2346873955.py:9: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = res + self.func2(ys[i],torch.reshape(xs[i],(4,1)))
# /tmp/ipykernel_2095463/2346873955.py:10: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = res + self.func2(ys[5],torch.reshape(xs[5],(4,1)))

# %%
print(gt[-1])
# Out:
# tensor([ 2.4077,  2.4077,  2.4077,  2.4077,  2.4077,  2.4077,  2.4077,  2.4077,
#          2.4077,  2.4077,  2.4077,  2.4077,  2.4077,  2.4077,  2.4077,  2.4077,
#         11.3500, 11.3500, 11.3500, 11.3500, 11.3500, 11.3500, 11.3500, 11.3500,
#         11.3500, 11.3500, 11.3500, 11.3500, 11.3500, 11.3500, 11.3500, 11.3500,
#          1.7521,  1.7521,  1.7521,  1.7521,  1.7521,  1.7521,  1.7521,  1.7521,
#          1.7521,  1.7521,  1.7521,  1.7521,  1.7521,  1.7521,  1.7521,  1.7521,
#          7.9500,  7.9500,  7.9500,  7.9500,  7.9500,  7.9500,  7.9500,  7.9500,
#          7.9500,  7.9500,  7.9500,  7.9500,  7.9500,  7.9500,  7.9500,  7.9500])

# %%
mean_absolute_error(gt[-1],preds[-1])
# Out:
# 5.744853

# %%
mean_squared_error(gt[-1],preds[-1])
# Out:
# 47.780228

# %%
math.sqrt(mean_squared_error(gt[-1],preds[-1]))
# Out:
# 6.912324331303676
