# %%
from fastai.vision.all import *
import fastai
import timm
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
# Out:
# /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")

# %%
import torch
torch.cuda.set_device(0)

# %%
df = pd.read_csv('data/wheat_new.csv',decimal=',')

# %%
name = 'vit_base_patch16_384'

# %%
df
# Out:
#      Unnamed: 0                 file  DAS  plot nº photo nº species  \
# 0             0   20220517_1 (1).JPG   96        1     (1).   wheat
# 1             1   20220517_1 (2).JPG   96        1     (2).   wheat
# 2             2   20220517_1 (3).JPG   96        1     (3).   wheat
# 3             3   20220517_1 (4).JPG   96        1     (4).   wheat
# 4             4   20220602_1 (1).JPG  112        1     (1).   wheat
# ..          ...                  ...  ...      ...      ...     ...
# 251         251  20220615_25 (4).JPG  125       25     (4).   wheat
# 252         252  20220701_25 (1).JPG  141       25     (1).   wheat
# 253         253  20220701_25 (2).JPG  141       25     (2).   wheat
# 254         254  20220701_25 (3).JPG  141       25     (3).   wheat
# 255         255  20220701_25 (4).JPG  141       25     (4).   wheat
#
#     water_treatment management  plot m2  avg_water (L m-2)  ...  \
# 0                ww       conv       12          3096.2375  ...
# 1                ww       conv       12          3096.2375  ...
# 2                ww       conv       12          3096.2375  ...
# 3                ww       conv       12          3096.2375  ...
# 4                ww       conv       12          3096.2375  ...
# ..              ...        ...      ...                ...  ...
# 251               d       conv       12          2752.8000  ...
# 252               d       conv       12          2752.8000  ...
# 253               d       conv       12          2752.8000  ...
# 254               d       conv       12          2752.8000  ...
# 255               d       conv       12          2752.8000  ...
#
#      P (kg microplot-1)  K (kg microplot-1)  avg_height        GA       GGA  \
# 0                 0.072               0.072     46.9715  0.959407  0.904393
# 1                 0.072               0.072     46.9715  0.963030  0.905523
# 2                 0.072               0.072     46.9715  0.953708  0.898722
# 3                 0.072               0.072     46.9715  0.957117  0.898772
# 4                 0.072               0.072     46.9715  0.892348  0.791199
# ..                  ...                 ...         ...       ...       ...
# 251               0.072               0.072     55.2110  0.788544  0.323428
# 252               0.072               0.072     55.2110  0.031868  0.009072
# 253               0.072               0.072     55.2110  0.025828  0.006849
# 254               0.072               0.072     55.2110  0.022065  0.004773
# 255               0.072               0.072     55.2110  0.026765  0.007124
#
#            CSI  NGRDIveg     TGIveg  final yield (kg)  dataset
# 0     5.734098    0.1324  2569.2709              9.15    train
# 1     5.971505    0.1316  2648.0105              9.15    train
# 2     5.765430    0.1331  2736.4337              9.15    train
# 3     6.095965    0.1267  2550.8238              9.15    train
# 4    11.335180    0.1008  1880.2128              9.15    train
# ..         ...       ...        ...               ...      ...
# 251  58.984136    0.0491  2277.6824              7.95     test
# 252  71.532905    0.0342   946.1760              7.95     test
# 253  73.483356    0.0314   867.4491              7.95     test
# 254  78.367629    0.0196   855.3556              7.95     test
# 255  73.384338    0.0265   979.4368              7.95     test
#
# [256 rows x 21 columns]

# %%
scaler = MinMaxScaler()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'file', 'DAS', 'plot nº', 'photo nº', 'species',
#        'water_treatment', 'management', 'plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)', 'dataset'],
#       dtype='object')

# %%
dftrain = df[(df.dataset=='train')]
# dftrain.loc[:,['plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)']] = scaler.fit_transform(dftrain[['plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)']])
dfvalid = df[(df.dataset=='validation')]
dftest = df[(df.dataset=='test')]
# dfvalid.loc[:,['plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)']] = scaler.transform(dfvalid[['plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)']])        
# dftest.loc[:,['plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)']] = scaler.transform(dftest[['plot m2', 'avg_water (L m-2)',
#        'N (kg microplot-1)', 'P (kg microplot-1)', 'K (kg microplot-1)',
#        'avg_height', 'GA', 'GGA', 'CSI', 'NGRDIveg', 'TGIveg',
#        'final yield (kg)']])

# %%
dftrain = pd.concat([dftrain,dfvalid])

# %%
df = pd.concat([dftrain,dftest])

# %%
dftrain.loc[:,'dataset'] =  dftrain['dataset'].apply(lambda x: x=='validation')
df.loc[:,'dataset'] =  df['dataset'].apply(lambda x: x=='test')

# %%
# dftrain.loc[:,'final yield (kg)'] = dftrain['final yield (kg)'].apply(lambda x : (x - 0.8579)/(10.55-0.8579))
# df.loc[:,'final yield (kg)'] = df['final yield (kg)'].apply(lambda x : (x - 0.8579)/(10.55-0.8579))

# %%
from fastai.vision.all import *
callbacks = [
    ShowGraphCallback(),
    # EarlyStoppingCallback(patience=5),
    SaveModelCallback(fname=name+'_all_new'), #convnext_yield_all_minmax
    # ReduceLROnPlateau()
]

# %%
from fastai.metrics import mae,rmse,mse

# %%
db = DataBlock(blocks = (ImageBlock,
                         RegressionBlock(),RegressionBlock(),RegressionBlock(),RegressionBlock(),
                         RegressionBlock(),RegressionBlock(),RegressionBlock(),RegressionBlock(),
                         RegressionBlock(),RegressionBlock(),RegressionBlock(),RegressionBlock()),
                 get_x=[ColReader('file',pref='wheat_all/')],
                 get_y=[#ColReader('species'),
                        #ColReader('water_treatment'),
                        #ColReader('management'),
                        ColReader('plot m2'),
                        ColReader('avg_water (L m-2)'),
                        ColReader('N (kg microplot-1)'),
                        ColReader('P (kg microplot-1)'),
                        ColReader('K (kg microplot-1)'),
                        ColReader('avg_height'),
                        ColReader('GA'),
                        ColReader('GGA'),
                        ColReader('CSI'),
                        ColReader('NGRDIveg'),
                        ColReader('TGIveg'),
                        ColReader('final yield (kg)')],
                 splitter=ColSplitter(col='dataset'),    
                 item_tfms = Resize(512),
                 batch_tfms=[*aug_transforms(size=384,flip_vert=True,
                                            max_zoom=1.0), Normalize.from_stats(*imagenet_stats)],
               n_inp=1)
dls = db.dataloaders(dftrain,bs=4)

# %%
class MultiInputModel(Module):
  "A three-headed model given a `body` and `n` output features"
  def __init__(self, body:nn.Sequential):
    nf = 1
    self.body = body
    #self.water_treatment = create_head(nf, 4)
    #self.management = create_head(nf, 2)
    self.avg_water = create_head(nf,1)
    self.n = create_head(nf,1)
    self.p = create_head(nf,1)
    self.k = create_head(nf,1)
    self.avg_height = create_head(nf,1)
    self.ga = create_head(nf,1)
    self.gga = create_head(nf,1)
    self.csi = create_head(nf,1)
    self.NGRDIveg = create_head(nf,1)
    self.TGIveg = create_head(nf,1)
    self.yieldprod = create_head(nf,1)

    
    
  
  def forward(self, x):
    y = self.body(x)
    return [
        #self.water_treatment(y),
        #self.management(y),
        self.avg_water(y),
        self.n(y),
        self.p(y),
        self.k(y),
        self.avg_height(y),
        self.ga(y),
        self.gga(y),
        self.csi(y),
        self.NGRDIveg(y),
        self.TGIveg(y),
        self.yieldprod(y)]

# %%
model = timm.create_model(name,num_classes=1,pretrained=True)
body = nn.Sequential(*list(model.children())[:-1])
net = MultiInputModel(body)

# %%
class CombinationLoss(Module):
    "Cross Entropy Loss on multiple targets"
    def __init__(self, func1=F.cross_entropy,func2=F.mse_loss, weights=[2, 1]):
        self.func1, self.func2, self.w = func2, func2, weights

    def forward(self, xs, *ys, reduction='mean'):
        res = self.func2(ys[0],torch.reshape(xs[0],(4,1)))
        for i in range(1,10):
            res = res + self.func2(ys[i],torch.reshape(xs[i],(4,1)))
        res = res + self.func2(ys[10],torch.reshape(xs[10],(4,1)))
        return res

# %%
learn = Learner(dls, net, loss_func=CombinationLoss(),cbs=callbacks)

# %%
# learn.lr_find()

# %%
learn.freeze()

# %%
learn.fit_one_cycle(50,lr_max=1e-3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>16308298.000000</td>
#       <td>17576512.000000</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>16330504.000000</td>
#       <td>17587170.000000</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>16329825.000000</td>
#       <td>17580736.000000</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>16396264.000000</td>
#       <td>17588352.000000</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>16350218.000000</td>
#       <td>17579542.000000</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>16365151.000000</td>
#       <td>17574414.000000</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>16244548.000000</td>
#       <td>17576788.000000</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>16326529.000000</td>
#       <td>17567502.000000</td>
#       <td>00:40</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>16318599.000000</td>
#       <td>17549452.000000</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>16332043.000000</td>
#       <td>17524188.000000</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>16289710.000000</td>
#       <td>17502058.000000</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>16206329.000000</td>
#       <td>17424094.000000</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>16131741.000000</td>
#       <td>17342466.000000</td>
#       <td>00:40</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>16043682.000000</td>
#       <td>17374556.000000</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>16026314.000000</td>
#       <td>17279170.000000</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>15898760.000000</td>
#       <td>17111668.000000</td>
#       <td>00:40</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>15827173.000000</td>
#       <td>16796870.000000</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>15817005.000000</td>
#       <td>16288620.000000</td>
#       <td>00:40</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>15636031.000000</td>
#       <td>16951620.000000</td>
#       <td>00:40</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>15523441.000000</td>
#       <td>16518105.000000</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>15392785.000000</td>
#       <td>16525179.000000</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>15164328.000000</td>
#       <td>15956608.000000</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>14976349.000000</td>
#       <td>15833248.000000</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>14885027.000000</td>
#       <td>15973236.000000</td>
#       <td>00:39</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>14682639.000000</td>
#       <td>15379616.000000</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>14522309.000000</td>
#       <td>15535157.000000</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>14398616.000000</td>
#       <td>15314442.000000</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>14217243.000000</td>
#       <td>15204352.000000</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>14038770.000000</td>
#       <td>14913509.000000</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>13785702.000000</td>
#       <td>14850746.000000</td>
#       <td>00:44</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>13650212.000000</td>
#       <td>14720974.000000</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>13532719.000000</td>
#       <td>14568382.000000</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>13332066.000000</td>
#       <td>14465652.000000</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>13287378.000000</td>
#       <td>14310502.000000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>13234300.000000</td>
#       <td>14272344.000000</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>13075497.000000</td>
#       <td>14055478.000000</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>12976853.000000</td>
#       <td>14077860.000000</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>12976059.000000</td>
#       <td>14015411.000000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>12887332.000000</td>
#       <td>13918818.000000</td>
#       <td>00:32</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>12759474.000000</td>
#       <td>13839474.000000</td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>12835729.000000</td>
#       <td>13786918.000000</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>12692433.000000</td>
#       <td>13881474.000000</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>12605698.000000</td>
#       <td>13770700.000000</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>12533135.000000</td>
#       <td>13740182.000000</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>12534408.000000</td>
#       <td>13742425.000000</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>12589165.000000</td>
#       <td>13717780.000000</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>12494345.000000</td>
#       <td>13714450.000000</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>12686961.000000</td>
#       <td>13715312.000000</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>12658986.000000</td>
#       <td>13719306.000000</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>12569749.000000</td>
#       <td>13702706.000000</td>
#       <td>00:50</td>
#     </tr>
#   </tbody>
# </table>
# /tmp/ipykernel_3160007/2185423817.py:7: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = self.func2(ys[0],torch.reshape(xs[0],(4,1)))
# /tmp/ipykernel_3160007/2185423817.py:9: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = res + self.func2(ys[i],torch.reshape(xs[i],(4,1)))
# /tmp/ipykernel_3160007/2185423817.py:10: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = res + self.func2(ys[10],torch.reshape(xs[10],(4,1)))
# Better model found at epoch 0 with valid_loss value: 17576512.0.
# Better model found at epoch 5 with valid_loss value: 17574414.0.
# Better model found at epoch 7 with valid_loss value: 17567502.0.
# Better model found at epoch 8 with valid_loss value: 17549452.0.
# Better model found at epoch 9 with valid_loss value: 17524188.0.
# Better model found at epoch 10 with valid_loss value: 17502058.0.
# Better model found at epoch 11 with valid_loss value: 17424094.0.
# Better model found at epoch 12 with valid_loss value: 17342466.0.
# Better model found at epoch 14 with valid_loss value: 17279170.0.
# Better model found at epoch 15 with valid_loss value: 17111668.0.
# Better model found at epoch 16 with valid_loss value: 16796870.0.
# Better model found at epoch 17 with valid_loss value: 16288620.0.
# Better model found at epoch 21 with valid_loss value: 15956608.0.
# Better model found at epoch 22 with valid_loss value: 15833248.0.
# Better model found at epoch 24 with valid_loss value: 15379616.0.
# Better model found at epoch 26 with valid_loss value: 15314442.0.
# Better model found at epoch 27 with valid_loss value: 15204352.0.
# Better model found at epoch 28 with valid_loss value: 14913509.0.
# Better model found at epoch 29 with valid_loss value: 14850746.0.
# Better model found at epoch 30 with valid_loss value: 14720974.0.
# Better model found at epoch 31 with valid_loss value: 14568382.0.
# Better model found at epoch 32 with valid_loss value: 14465652.0.
# Better model found at epoch 33 with valid_loss value: 14310502.0.
# Better model found at epoch 34 with valid_loss value: 14272344.0.
# Better model found at epoch 35 with valid_loss value: 14055478.0.
# Better model found at epoch 37 with valid_loss value: 14015411.0.
# Better model found at epoch 38 with valid_loss value: 13918818.0.
# Better model found at epoch 39 with valid_loss value: 13839474.0.
# Better model found at epoch 40 with valid_loss value: 13786918.0.
# Better model found at epoch 42 with valid_loss value: 13770700.0.
# Better model found at epoch 43 with valid_loss value: 13740182.0.
# Better model found at epoch 45 with valid_loss value: 13717780.0.
# Better model found at epoch 46 with valid_loss value: 13714450.0.
# Better model found at epoch 49 with valid_loss value: 13702706.0.

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(50,lr_max=1e-4)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>12542229.000000</td>
#       <td>13690629.000000</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>12507567.000000</td>
#       <td>13703607.000000</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>12479996.000000</td>
#       <td>13687675.000000</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>12478965.000000</td>
#       <td>13678485.000000</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>12536808.000000</td>
#       <td>13703204.000000</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>12396115.000000</td>
#       <td>13697066.000000</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>12520471.000000</td>
#       <td>13665688.000000</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>12496305.000000</td>
#       <td>13644094.000000</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>12501230.000000</td>
#       <td>13631879.000000</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>12481054.000000</td>
#       <td>13579184.000000</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>12428085.000000</td>
#       <td>13588156.000000</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>12420446.000000</td>
#       <td>13536519.000000</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>12431585.000000</td>
#       <td>13526367.000000</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>12333719.000000</td>
#       <td>13469074.000000</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>12332602.000000</td>
#       <td>13453683.000000</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>12393567.000000</td>
#       <td>13431851.000000</td>
#       <td>00:49</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>12313861.000000</td>
#       <td>13400962.000000</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>12341980.000000</td>
#       <td>13333111.000000</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>12379907.000000</td>
#       <td>13341970.000000</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>12292795.000000</td>
#       <td>13288676.000000</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>12196344.000000</td>
#       <td>13276578.000000</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>12130799.000000</td>
#       <td>13239780.000000</td>
#       <td>00:53</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>12059229.000000</td>
#       <td>13249270.000000</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>12086362.000000</td>
#       <td>13181460.000000</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>12051159.000000</td>
#       <td>13163109.000000</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>12029242.000000</td>
#       <td>13115906.000000</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>11996499.000000</td>
#       <td>13107603.000000</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>11942123.000000</td>
#       <td>13075858.000000</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>11888878.000000</td>
#       <td>13072361.000000</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>11959052.000000</td>
#       <td>13047305.000000</td>
#       <td>00:50</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>11922904.000000</td>
#       <td>13075491.000000</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>11845608.000000</td>
#       <td>13014055.000000</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>11887584.000000</td>
#       <td>13004220.000000</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>11879764.000000</td>
#       <td>13012170.000000</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>11791884.000000</td>
#       <td>13020489.000000</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>11816717.000000</td>
#       <td>12961196.000000</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>11864326.000000</td>
#       <td>12972387.000000</td>
#       <td>00:48</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>11808445.000000</td>
#       <td>12950024.000000</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>11883639.000000</td>
#       <td>12931405.000000</td>
#       <td>00:52</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>11926034.000000</td>
#       <td>12924666.000000</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>11755967.000000</td>
#       <td>12940641.000000</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>11753396.000000</td>
#       <td>12938686.000000</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>11781199.000000</td>
#       <td>12960010.000000</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>11792622.000000</td>
#       <td>12945570.000000</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>11722377.000000</td>
#       <td>12956368.000000</td>
#       <td>00:51</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>11864715.000000</td>
#       <td>12939824.000000</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>11864685.000000</td>
#       <td>12935683.000000</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>11859155.000000</td>
#       <td>12922235.000000</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>11780220.000000</td>
#       <td>12945306.000000</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>11785747.000000</td>
#       <td>12927383.000000</td>
#       <td>00:35</td>
#     </tr>
#   </tbody>
# </table>
# /tmp/ipykernel_3160007/2185423817.py:7: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = self.func2(ys[0],torch.reshape(xs[0],(4,1)))
# /tmp/ipykernel_3160007/2185423817.py:9: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = res + self.func2(ys[i],torch.reshape(xs[i],(4,1)))
# /tmp/ipykernel_3160007/2185423817.py:10: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = res + self.func2(ys[10],torch.reshape(xs[10],(4,1)))
# Better model found at epoch 0 with valid_loss value: 13690629.0.
# Better model found at epoch 2 with valid_loss value: 13687675.0.
# Better model found at epoch 3 with valid_loss value: 13678485.0.
# Better model found at epoch 6 with valid_loss value: 13665688.0.
# Better model found at epoch 7 with valid_loss value: 13644094.0.
# Better model found at epoch 8 with valid_loss value: 13631879.0.
# Better model found at epoch 9 with valid_loss value: 13579184.0.
# Better model found at epoch 11 with valid_loss value: 13536519.0.
# Better model found at epoch 12 with valid_loss value: 13526367.0.
# Better model found at epoch 13 with valid_loss value: 13469074.0.
# Better model found at epoch 14 with valid_loss value: 13453683.0.
# Better model found at epoch 15 with valid_loss value: 13431851.0.
# Better model found at epoch 16 with valid_loss value: 13400962.0.
# Better model found at epoch 17 with valid_loss value: 13333111.0.
# Better model found at epoch 19 with valid_loss value: 13288676.0.
# Better model found at epoch 20 with valid_loss value: 13276578.0.
# Better model found at epoch 21 with valid_loss value: 13239780.0.
# Better model found at epoch 23 with valid_loss value: 13181460.0.
# Better model found at epoch 24 with valid_loss value: 13163109.0.
# Better model found at epoch 25 with valid_loss value: 13115906.0.
# Better model found at epoch 26 with valid_loss value: 13107603.0.
# Better model found at epoch 27 with valid_loss value: 13075858.0.
# Better model found at epoch 28 with valid_loss value: 13072361.0.
# Better model found at epoch 29 with valid_loss value: 13047305.0.
# Better model found at epoch 31 with valid_loss value: 13014055.0.
# Better model found at epoch 32 with valid_loss value: 13004220.0.
# Better model found at epoch 35 with valid_loss value: 12961196.0.
# Better model found at epoch 37 with valid_loss value: 12950024.0.
# Better model found at epoch 38 with valid_loss value: 12931405.0.
# Better model found at epoch 39 with valid_loss value: 12924666.0.
# Better model found at epoch 47 with valid_loss value: 12922235.0.

# %%
dls = db.dataloaders(df,bs=4)
learn.dls=dls

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
preds,gt = learn.get_preds()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# /tmp/ipykernel_3160007/2185423817.py:7: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = self.func2(ys[0],torch.reshape(xs[0],(4,1)))
# /tmp/ipykernel_3160007/2185423817.py:9: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = res + self.func2(ys[i],torch.reshape(xs[i],(4,1)))
# /tmp/ipykernel_3160007/2185423817.py:10: UserWarning: Using a target size (torch.Size([4, 1])) that is different to the input size (torch.Size([4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   res = res + self.func2(ys[10],torch.reshape(xs[10],(4,1)))

# %%
mean_absolute_error(gt,preds)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 mean_absolute_error(gt,preds)
#
# File /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/sklearn/metrics/_regression.py:196, in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
#     141 def mean_absolute_error(
#     142     y_true, y_pred, *, sample_weight=None, multioutput="uniform_average"
#     143 ):
#     144     """Mean absolute error regression loss.
#     145
#     146     Read more in the :ref:`User Guide <mean_absolute_error>`.
#    (...)
#     194     0.85...
#     195     """
# --> 196     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     197         y_true, y_pred, multioutput
#     198     )
#     199     check_consistent_length(y_true, y_pred, sample_weight)
#     200     output_errors = np.average(np.abs(y_pred - y_true), weights=sample_weight, axis=0)
#
# File /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/sklearn/metrics/_regression.py:100, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      66 def _check_reg_targets(y_true, y_pred, multioutput, dtype="numeric"):
#      67     """Check that y_true and y_pred belong to the same regression task.
#      68
#      69     Parameters
#    (...)
#      98         correct keyword.
#      99     """
# --> 100     check_consistent_length(y_true, y_pred)
#     101     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     102     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# File /grupoa/config/miniconda3/envs/fastai/lib/python3.10/site-packages/sklearn/utils/validation.py:387, in check_consistent_length(*arrays)
#     385 uniques = np.unique(lengths)
#     386 if len(uniques) > 1:
# --> 387     raise ValueError(
#     388         "Found input variables with inconsistent numbers of samples: %r"
#     389         % [int(l) for l in lengths]
#     390     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [12, 11]

# %%
mean_squared_error(gt,preds)

# %%
math.sqrt(mean_squared_error(gt,preds))
